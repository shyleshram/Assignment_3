# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')
people = {
    "first" : ["Corey", "Jane", "John"],
    "last" : ["Schafer", "Doe", "Doe"],
    "email" : ["CoreyMSchafer@gmail.com", "JaneDoe@email.com","JohnDoe@email.com"]
}
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1.columns = ['first_name','last_name','email']

# %%
df1
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df1.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df1.columns = [x.upper() for x in df1.columns]

# %%
df1.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'EMAIL'], dtype='object')

# %%
df1
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df1.columns = [x.replace('T','T ') for x in df1.columns ]

# %%
df1
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
# update only for some columns -> use rename(columns={})

# %%
df1.columns = [x.lower() for x in df1.columns]

# %%
df1.columns = [x.replace(' ','') for x in df1.columns]

# %%
df1
# Out:
#   firstname lastname                    email
# 0     Corey  Schafer  CoreyMSchafer@gmail.com
# 1      Jane      Doe        JaneDoe@email.com
# 2      John      Doe        JohnDoe@email.com

# %%
df1.rename(columns={'firstname':'first','lastname':'last'}, inplace=True)

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df1.loc[2,'last'] = 'Smith'

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df1.loc[2] = ['John','smith','JohnSmith@email..com']

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    smith     JohnSmith@email..com

# %%
df1.loc[2,['last','email']] = ['Doe','JohnDoe@email.com']

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df1.loc[2,'last'] = 'Smith'

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df1.at[2,'last'] = 'Smith'

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
filt = df1['last'] == 'Smith'

# %%
df1.loc[filt,'last'] = 'Doe'

# %%
df
# Out:
#        first last                    email
# 0      Corey  Doe  CoreyMSchafer@gmail.com
# 1       Jane  Doe        JaneDoe@email.com
# 2       John  Doe        JohnDoe@email.com
# Smith    NaN  Doe                      NaN

# %%
df1.drop('Smith')
# Out:
#    first last                    email
# 0  Corey  Doe  CoreyMSchafer@gmail.com
# 1   Jane  Doe        JaneDoe@email.com
# 2   John  Doe        JohnDoe@email.com

# %%
filt = (df1['email'] == 'JohnDoe@email.com')
df1[filt]['last'] = 'Smith'
# Out:
# C:\Users\Shylesh_Ram\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1.drop('Smith',inplace=True)

# %%
df1
# Out:
#    first last                    email
# 0  Corey  Doe  CoreyMSchafer@gmail.com
# 1   Jane  Doe        JaneDoe@email.com
# 2   John  Doe        JohnDoe@email.com

# %%
filt = df1['email']=='JohnDoe@email.com'
df1[filt]['last'] = 'Smith'
# Out:
# C:\Users\Shylesh_Ram\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1
# Out:
#    first last                    email
# 0  Corey  Doe  CoreyMSchafer@gmail.com
# 1   Jane  Doe        JaneDoe@email.com
# 2   John  Doe        JohnDoe@email.com

# %%
filt = df1['email']=='JohnDoe@email.com'
df1.loc[filt, 'last'] = 'Smith'

# %%
df1
# Out:
#    first   last                    email
# 0  Corey    Doe  CoreyMSchafer@gmail.com
# 1   Jane    Doe        JaneDoe@email.com
# 2   John  Smith        JohnDoe@email.com

# %%
df1['email'] = df1['email'].str.lower()

# %%
df1
# Out:
#    first   last                    email
# 0  Corey    Doe  coreymschafer@gmail.com
# 1   Jane    Doe        janedoe@email.com
# 2   John  Smith        johndoe@email.com

# %%
# 4 methods
# apply() -> both dataframes and series objects(used to call functions on our values)
# map() -> Series. used to substitute each value in a Series with other value. with dictionaries usage
# applymap() -> only for dataframes
# replace() -> works with Series. Substitute values in series only with the specified entity

# %%
df1['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper();

# %%
df1['email'] = df1['email'].apply(update_email)

# %%
df1
# Out:
#    first   last                    email
# 0  Corey    Doe  COREYMSCHAFER@GMAIL.COM
# 1   Jane    Doe        JANEDOE@EMAIL.COM
# 2   John  Smith        JOHNDOE@EMAIL.COM

# %%
df1['email'] = df1['email'].apply(lambda x: x.lower())

# %%
df1
# Out:
#    first   last                    email
# 0  Corey    Doe  coreymschafer@gmail.com
# 1   Jane    Doe        janedoe@email.com
# 2   John  Smith        johndoe@email.com

# %%
df1.apply(len) # applies to every series in the dataframe
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df1.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df1.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df1.apply(pd.Series.max)
# Out:
# first                 John
# last                 Smith
# email    johndoe@email.com
# dtype: object

# %%
df1.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df1.apply(lambda x: x.max())
# Out:
# first                 John
# last                 Smith
# email    johndoe@email.com
# dtype: object

# %%
# apply() -> work with every values in a Series
        # -> work with every Series in a DataFrame
# applymap() -> work with every values in a DataFrame
# map() -> work only with series
# replace() -> work only with seires

# %%
df1.applymap(len)
# Out:
#    first  last  email
# 0      5     3     23
# 1      4     3     17
# 2      4     5     17

# %%
df1
# Out:
#    first   last                    email
# 0  Corey    Doe  coreymschafer@gmail.com
# 1   Jane    Doe        janedoe@email.com
# 2   John  Smith        johndoe@email.com

# %%
df1.applymap(str.upper) # error with numbers when used string methods
# Out:
#    first   last                    email
# 0  COREY    DOE  COREYMSCHAFER@GMAIL.COM
# 1   JANE    DOE        JANEDOE@EMAIL.COM
# 2   JOHN  SMITH        JOHNDOE@EMAIL.COM

# %%
df1['first'].map({'Corey':'Chris','Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df1
# Out:
#    first   last                    email
# 0  Corey    Doe  coreymschafer@gmail.com
# 1   Jane    Doe        janedoe@email.com
# 2   John  Smith        johndoe@email.com

# %%
df1['first'].replace({'Corey':'Chris','Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.rename(columns={'ConvertedComp':'USDSalary'}, inplace=True)

# %%
df.rename(columns={'USDSalary':'SalaryUSD'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'SalaryUSD', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['SalaryUSD']
# Out:
# 0             NaN
# 1             NaN
# 2          8820.0
# 3         61000.0
# 4             NaN
# 5        366420.0
# 6             NaN
# 7             NaN
# 8         95179.0
# 9         13293.0
# 10            NaN
# 11            NaN
# 12        90000.0
# 13        57060.0
# 14            NaN
# 15       455352.0
# 16        65277.0
# 17        21996.0
# 18        31140.0
# 19        41244.0
# 20            NaN
# 21       103000.0
# 22        69000.0
# 23        26388.0
# 24         6300.0
# 25       114000.0
# 26            NaN
# 27            NaN
# 28       100000.0
# 29        90417.0
#            ...
# 88853         NaN
# 88854         NaN
# 88855         NaN
# 88856         NaN
# 88857         NaN
# 88858         NaN
# 88859         NaN
# 88860         NaN
# 88861         NaN
# 88862         NaN
# 88863         NaN
# 88864         NaN
# 88865         NaN
# 88866         NaN
# 88867         NaN
# 88868         NaN
# 88869         NaN
# 88870         NaN
# 88871         NaN
# ...

# %%
def update_hobby(hob):
    if hob == 'Yes':
        hob = 1
    else:
        hob = 0;
    return hob
df['Hobbyist'] = df['Hobbyist'].apply(update_hobby)

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True,'No':False})

# %%
df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# 5               6  I am not primarily a developer, but I write co...
# 6               7                     I am a developer by profession
# 7               8                        I code primarily as a hobby
# 8               9                     I am a developer by profession
# 9              10                     I am a developer by profession
# 10             11                        I code primarily as a hobby
# 11             12             I am a student who is learning to code
# 12             13                     I am a developer by profession
# ...
