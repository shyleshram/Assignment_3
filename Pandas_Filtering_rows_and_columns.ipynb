# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')
people = {
    "first" : ["Corey", "Jane", "John"],
    "last" : ["Schafer", "Doe", "Doe"],
    "email" : ["CoreyMSchafer@gmail.com", "JaneDoe@email.com","JohnDoe@email.com"]
}
df1 = pd.DataFrame(people)

# %%
df1['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = df1['last'] == 'Doe'

# %%
df1[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df1[df1['last'] == 'Doe']
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df1.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = (df1['last'] == 'Doe')

# %%
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df1[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df1.loc[filt, ['last','email']]
# Out:
#   last              email
# 1  Doe  JaneDoe@email.com
# 2  Doe  JohnDoe@email.com

# %%
# & |

# %%
filt = ((df1['last']=='Doe') & (df1['first']=='John'))

# %%
df1.loc[filt, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = ((df1['last']=='Schafer') | (df1['first']=='John'))

# %%
df1.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# 11             12             I am a student who is learning to code       No
# 12             13                     I am a developer by profession      Yes
# 13             14                     I am a developer by profession      Yes
# 14             15             I am a student who is learning to code      Yes
# 15             16                     I am a developer by profession      Yes
# 16             17                     I am a developer by profession      Yes
# 17             18  I am not primarily a developer, but I write co...      Yes
# 18             19                     I am a developer by profession      Yes
# 19             20  I am not primarily a developer, but I write co...       No
# 20             21                        I code primarily as a hobby      Yes
# 21             22                     I am a developer by profession      Yes
# 22             23                     I am a developer by profession      Yes
# 23             24                     I am a developer by profession      Yes
# 24             25                     I am a developer by profession       No
# 25             26                     I am a developer by profession      Yes
# 26             27  I used to be a developer by profession, but no...      Yes
# 27             28                     I am a developer by profession      Yes
# 28             29                     I am a developer by profession      Yes
# 29             30                     I am a developer by profession       No
# 30             31             I am a student who is learning to code       No
# 31             32                     I am a developer by profession       No
# 32             33                     I am a developer by profession       No
# 33             34             I am a student who is learning to code      Yes
# 34             35                     I am a developer by profession       No
# 35             36                     I am a developer by profession      Yes
# 36             37                        I code primarily as a hobby      Yes
# 37             38                     I am a developer by profession      Yes
# 38             39                     I am a developer by profession      Yes
# 39             40             I am a student who is learning to code      Yes
# 40             41                     I am a developer by profession      Yes
# 41             42                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88841       82789                                                NaN      Yes
# 88842       82805                                                NaN      Yes
# 88843       83000                                                NaN       No
# 88844       83397                                                NaN      Yes
# 88845       83511                                                NaN       No
# 88846       83612                                                NaN      Yes
# 88847       83648                                                NaN       No
# 88848       83709                                                NaN      Yes
# 88849       83777                                                NaN       No
# 88850       83786                                                NaN       No
# 88851       83800                                                NaN       No
# 88852       83862                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88854       84539                                                NaN      Yes
# 88855       85182                                                NaN       No
# 88856       85208                                                NaN       No
# 88857       85396                                                NaN       No
# 88858       85538                                                NaN       No
# 88859       85642                                                NaN       No
# 88860       85738                                                NaN      Yes
# 88861       85744                                                NaN       No
# 88862       85955                                                NaN      Yes
# 88863       85961                                                NaN      Yes
# 88864       86012                                                NaN      Yes
# 88865       86566                                                NaN      Yes
# 88866       86638                                                NaN      Yes
# 88867       86806                                                NaN      Yes
# 88868       86980                                                NaN       No
# 88869       86999                                                NaN       No
# 88870       87352                                                NaN      Yes
# 88871       87386                                                NaN      Yes
# 88872       87739                                                NaN      Yes
# 88873       88062                                                NaN       No
# 88874       88076                                                NaN       No
# 88875       88182                                                NaN      Yes
# 88876       88212                                                NaN       No
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# 5                                                  Never
# 6                                                  Never
# 7                                Less than once per year
# 8                             Once a month or more often
# 9                             Once a month or more often
# 10                            Once a month or more often
# 11                                                 Never
# 12     Less than once a month but more than once per ...
# 13                               Less than once per year
# 14                                                 Never
# 15                                                 Never
# 16     Less than once a month but more than once per ...
# 17     Less than once a month but more than once per ...
# 18                                                 Never
# 19                                                 Never
# 20                            Once a month or more often
# 21                               Less than once per year
# 22                               Less than once per year
# 23                                                 Never
# 24                                                 Never
# 25                               Less than once per year
# 26                               Less than once per year
# 27                               Less than once per year
# 28     Less than once a month but more than once per ...
# 29     Less than once a month but more than once per ...
# 30                                                 Never
# 31                                                 Never
# 32     Less than once a month but more than once per ...
# 33                                                 Never
# 34                                                 Never
# 35     Less than once a month but more than once per ...
# 36                               Less than once per year
# 37                                                 Never
# 38                               Less than once per year
# 39                                                 Never
# 40                               Less than once per year
# 41     Less than once a month but more than once per ...
# ...                                                  ...
# 88841                         Once a month or more often
# 88842  Less than once a month but more than once per ...
# 88843                            Less than once per year
# 88844                            Less than once per year
# 88845                                              Never
# 88846                                              Never
# 88847                                              Never
# 88848                         Once a month or more often
# 88849                                              Never
# 88850                         Once a month or more often
# 88851                                              Never
# 88852                         Once a month or more often
# 88853                                              Never
# 88854  Less than once a month but more than once per ...
# 88855  Less than once a month but more than once per ...
# 88856                                              Never
# 88857  Less than once a month but more than once per ...
# 88858                                              Never
# 88859                            Less than once per year
# 88860                                              Never
# 88861                                              Never
# 88862                            Less than once per year
# 88863                            Less than once per year
# 88864                         Once a month or more often
# 88865  Less than once a month but more than once per ...
# 88866                                              Never
# 88867                         Once a month or more often
# 88868                                              Never
# 88869                                              Never
# 88870                            Less than once per year
# 88871  Less than once a month but more than once per ...
# 88872                            Less than once per year
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# 5      The quality of OSS and closed source software ...
# 6      The quality of OSS and closed source software ...
# 7      OSS is, on average, of HIGHER quality than pro...
# 8      The quality of OSS and closed source software ...
# 9      OSS is, on average, of HIGHER quality than pro...
# 10     The quality of OSS and closed source software ...
# 11     OSS is, on average, of HIGHER quality than pro...
# 12     OSS is, on average, of HIGHER quality than pro...
# 13     The quality of OSS and closed source software ...
# 14     OSS is, on average, of HIGHER quality than pro...
# 15     The quality of OSS and closed source software ...
# 16     The quality of OSS and closed source software ...
# 17     The quality of OSS and closed source software ...
# 18     The quality of OSS and closed source software ...
# 19     OSS is, on average, of HIGHER quality than pro...
# 20     OSS is, on average, of HIGHER quality than pro...
# 21     OSS is, on average, of HIGHER quality than pro...
# 22     The quality of OSS and closed source software ...
# 23     OSS is, on average, of HIGHER quality than pro...
# 24     OSS is, on average, of HIGHER quality than pro...
# 25     The quality of OSS and closed source software ...
# 26     OSS is, on average, of HIGHER quality than pro...
# 27     The quality of OSS and closed source software ...
# 28     OSS is, on average, of HIGHER quality than pro...
# 29     OSS is, on average, of HIGHER quality than pro...
# 30                                                   NaN
# 31     The quality of OSS and closed source software ...
# 32     OSS is, on average, of HIGHER quality than pro...
# 33     OSS is, on average, of HIGHER quality than pro...
# 34     OSS is, on average, of HIGHER quality than pro...
# 35     The quality of OSS and closed source software ...
# 36     OSS is, on average, of LOWER quality than prop...
# 37     OSS is, on average, of LOWER quality than prop...
# 38     The quality of OSS and closed source software ...
# 39     OSS is, on average, of HIGHER quality than pro...
# 40     OSS is, on average, of HIGHER quality than pro...
# 41     OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88841  The quality of OSS and closed source software ...
# 88842  The quality of OSS and closed source software ...
# 88843  OSS is, on average, of HIGHER quality than pro...
# 88844                                                NaN
# 88845  OSS is, on average, of LOWER quality than prop...
# 88846  OSS is, on average, of HIGHER quality than pro...
# 88847                                                NaN
# 88848  The quality of OSS and closed source software ...
# 88849                                                NaN
# 88850  The quality of OSS and closed source software ...
# 88851  OSS is, on average, of LOWER quality than prop...
# 88852  OSS is, on average, of HIGHER quality than pro...
# 88853  The quality of OSS and closed source software ...
# 88854  The quality of OSS and closed source software ...
# 88855  The quality of OSS and closed source software ...
# 88856  The quality of OSS and closed source software ...
# 88857  OSS is, on average, of HIGHER quality than pro...
# 88858  OSS is, on average, of HIGHER quality than pro...
# 88859  OSS is, on average, of LOWER quality than prop...
# 88860  The quality of OSS and closed source software ...
# 88861  OSS is, on average, of LOWER quality than prop...
# 88862  OSS is, on average, of LOWER quality than prop...
# 88863  The quality of OSS and closed source software ...
# 88864  OSS is, on average, of HIGHER quality than pro...
# 88865  OSS is, on average, of HIGHER quality than pro...
# 88866  OSS is, on average, of HIGHER quality than pro...
# 88867  OSS is, on average, of HIGHER quality than pro...
# 88868  The quality of OSS and closed source software ...
# 88869  OSS is, on average, of LOWER quality than prop...
# 88870                                                NaN
# 88871  OSS is, on average, of LOWER quality than prop...
# 88872  OSS is, on average, of HIGHER quality than pro...
# 88873  OSS is, on average, of LOWER quality than prop...
# 88874  OSS is, on average, of HIGHER quality than pro...
# 88875  OSS is, on average, of HIGHER quality than pro...
# 88876  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# 5                                     Employed full-time
# 6      Independent contractor, freelancer, or self-em...
# 7                     Not employed, but looking for work
# 8                                     Employed full-time
# 9                                     Employed full-time
# 10                                                   NaN
# 11                                    Employed part-time
# 12                                    Employed full-time
# 13                                    Employed full-time
# 14                    Not employed, but looking for work
# 15                                    Employed full-time
# 16                                    Employed full-time
# 17                                    Employed full-time
# 18                                    Employed full-time
# 19                                    Employed full-time
# 20                                                   NaN
# 21                                    Employed full-time
# 22                                    Employed full-time
# 23                                    Employed full-time
# 24                                    Employed full-time
# 25                                    Employed full-time
# 26                    Not employed, but looking for work
# 27                                    Employed full-time
# 28                                    Employed full-time
# 29                                    Employed full-time
# 30                Not employed, and not looking for work
# 31                                    Employed full-time
# 32                                    Employed full-time
# 33                    Not employed, but looking for work
# 34                                    Employed full-time
# 35                                    Employed full-time
# 36                                    Employed part-time
# 37                                    Employed full-time
# 38                                    Employed full-time
# 39     Independent contractor, freelancer, or self-em...
# 40                                    Employed part-time
# 41                                    Employed full-time
# ...                                                  ...
# 88841                                                NaN
# 88842  Independent contractor, freelancer, or self-em...
# 88843                                 Employed full-time
# 88844                 Not employed, but looking for work
# 88845                                 Employed full-time
# 88846                                 Employed full-time
# 88847                                                NaN
# 88848  Independent contractor, freelancer, or self-em...
# 88849                 Not employed, but looking for work
# 88850                                 Employed full-time
# 88851                                 Employed full-time
# 88852                                 Employed full-time
# 88853                                 Employed full-time
# 88854                                 Employed full-time
# 88855                                                NaN
# 88856                 Not employed, but looking for work
# 88857  Independent contractor, freelancer, or self-em...
# 88858             Not employed, and not looking for work
# 88859  Independent contractor, freelancer, or self-em...
# 88860             Not employed, and not looking for work
# 88861                                                NaN
# 88862             Not employed, and not looking for work
# 88863                                                NaN
# 88864                                 Employed full-time
# 88865                                            Retired
# 88866             Not employed, and not looking for work
# 88867                                 Employed part-time
# 88868                 Not employed, but looking for work
# 88869             Not employed, and not looking for work
# 88870             Not employed, and not looking for work
# 88871  Independent contractor, freelancer, or self-em...
# 88872                                 Employed part-time
# 88873                                                NaN
# 88874                                 Employed full-time
# 88875                                 Employed part-time
# 88876                                 Employed full-time
# 88877                 Not employed, but looking for work
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# 5                      Canada              No
# 6                     Ukraine              No
# 7                       India             NaN
# 8                 New Zealand              No
# 9                       India              No
# 10        Antigua and Barbuda  Yes, full-time
# 11                     Canada  Yes, full-time
# 12              United States              No
# 13                    Germany              No
# 14                      India  Yes, full-time
# 15             United Kingdom              No
# 16                  Australia              No
# 17         Russian Federation              No
# 18                     Brazil              No
# 19                  Lithuania              No
# 20                     Canada             NaN
# 21              United States              No
# 22              United States              No
# 23                     Israel              No
# 24               South Africa              No
# 25              United States              No
# 26                   Colombia  Yes, part-time
# 27                     Turkey              No
# 28              United States              No
# 29                Switzerland              No
# 30                     Canada              No
# 31              United States              No
# 32                  Argentina  Yes, full-time
# 33                  Sri Lanka              No
# 34              United States              No
# 35                    Germany  Yes, full-time
# 36                     Canada  Yes, full-time
# 37             Czech Republic              No
# 38              United States              No
# 39                    Denmark  Yes, full-time
# 40                   Malaysia  Yes, full-time
# 41                 Bangladesh              No
# ...                       ...             ...
# 88841          United Kingdom              No
# 88842      Russian Federation              No
# 88843                  Brazil              No
# 88844           United States              No
# 88845                     NaN             NaN
# 88846                Thailand             NaN
# 88847                     NaN             NaN
# 88848               Argentina  Yes, part-time
# 88849                     NaN             NaN
# 88850                 Germany              No
# 88851                     NaN             NaN
# 88852                   India  Yes, full-time
# 88853                   India  Yes, full-time
# 88854          United Kingdom  Yes, full-time
# 88855                  Canada             NaN
# 88856                     NaN             NaN
# 88857                  Sweden              No
# 88858                     NaN             NaN
# 88859           United States              No
# 88860                  Brazil  Yes, full-time
# 88861                     NaN             NaN
# 88862                   Egypt  Yes, part-time
# 88863          United Kingdom              No
# 88864                   India              No
# 88865             Switzerland              No
# 88866               Australia              No
# 88867                 Nigeria  Yes, part-time
# 88868                     NaN             NaN
# 88869                     NaN             NaN
# 88870             Netherlands              No
# 88871                   Italy  Yes, full-time
# 88872          Czech Republic  Yes, full-time
# 88873                     NaN             NaN
# 88874                     NaN             NaN
# 88875                Pakistan             NaN
# 88876                   Spain              No
# 88877           United States              No
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8      Some college/university study without earning ...
# 9            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 10                             Primary/elementary school
# 11     Some college/university study without earning ...
# 12           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13             Other doctoral degree (Ph.D, Ed.D., etc.)
# 14     Secondary school (e.g. American high school, G...
# 15           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 16              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 17           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 18     Some college/university study without earning ...
# 19           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 20                                                   NaN
# 21     Some college/university study without earning ...
# 22              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23                             Primary/elementary school
# 24                                      Associate degree
# 25     Some college/university study without earning ...
# 26     Some college/university study without earning ...
# 27              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 29              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 30                             Primary/elementary school
# 31                                      Associate degree
# 32           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 33                             Primary/elementary school
# 34              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 35     Secondary school (e.g. American high school, G...
# 36                                      Associate degree
# 37           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 38              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 39     Secondary school (e.g. American high school, G...
# 40              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 41     Secondary school (e.g. American high school, G...
# ...                                                  ...
# 88841  Secondary school (e.g. American high school, G...
# 88842  Some college/university study without earning ...
# 88843  Secondary school (e.g. American high school, G...
# 88844           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88845                                                NaN
# 88846        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88847                                                NaN
# 88848           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88849                                                NaN
# 88850          Other doctoral degree (Ph.D, Ed.D., etc.)
# 88851                                                NaN
# 88852           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88853           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88854           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88855                                                NaN
# 88856                                                NaN
# 88857                 Professional degree (JD, MD, etc.)
# 88858                                                NaN
# 88859                                   Associate degree
# 88860  Secondary school (e.g. American high school, G...
# 88861                                                NaN
# 88862  Secondary school (e.g. American high school, G...
# 88863          Other doctoral degree (Ph.D, Ed.D., etc.)
# 88864        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88865  Some college/university study without earning ...
# 88866  Some college/university study without earning ...
# 88867  Secondary school (e.g. American high school, G...
# 88868                                                NaN
# 88869                                                NaN
# 88870           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88871           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88872        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88873                                                NaN
# 88874                                                NaN
# 88875  Secondary school (e.g. American high school, G...
# 88876  Secondary school (e.g. American high school, G...
# 88877  Some college/university study without earning ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# 5                              Mathematics or statistics
# 6      Another engineering discipline (ex. civil, ele...
# 7      Computer science, computer engineering, or sof...
# 8      Computer science, computer engineering, or sof...
# 9                                                    NaN
# 10                                                   NaN
# 11                             Mathematics or statistics
# 12     Computer science, computer engineering, or sof...
# 13     Computer science, computer engineering, or sof...
# 14                                                   NaN
# 15                                                   NaN
# 16     Computer science, computer engineering, or sof...
# 17     Computer science, computer engineering, or sof...
# 18     Computer science, computer engineering, or sof...
# 19     Information systems, information technology, o...
# 20                                                   NaN
# 21                                                   NaN
# 22     Information systems, information technology, o...
# 23                                                   NaN
# 24     Computer science, computer engineering, or sof...
# 25     Computer science, computer engineering, or sof...
# 26     Information systems, information technology, o...
# 27     A business discipline (ex. accounting, finance...
# 28                                                   NaN
# 29     Computer science, computer engineering, or sof...
# 30                                                   NaN
# 31     Information systems, information technology, o...
# 32     A natural science (ex. biology, chemistry, phy...
# 33                                                   NaN
# 34     Information systems, information technology, o...
# 35                                                   NaN
# 36     A social science (ex. anthropology, psychology...
# 37     Computer science, computer engineering, or sof...
# 38     Computer science, computer engineering, or sof...
# 39                                                   NaN
# 40     Information systems, information technology, o...
# 41                                                   NaN
# ...                                                  ...
# 88841                                                NaN
# 88842                           I never declared a major
# 88843                                                NaN
# 88844  Computer science, computer engineering, or sof...
# 88845                                                NaN
# 88846                                                NaN
# 88847                                                NaN
# 88848  Computer science, computer engineering, or sof...
# 88849                                                NaN
# 88850  Computer science, computer engineering, or sof...
# 88851                                                NaN
# 88852                                                NaN
# 88853                      Web development or web design
# 88854  Computer science, computer engineering, or sof...
# 88855                                                NaN
# 88856                                                NaN
# 88857                                                NaN
# 88858                                                NaN
# 88859  Information systems, information technology, o...
# 88860                                                NaN
# 88861                                                NaN
# 88862                                                NaN
# 88863  Computer science, computer engineering, or sof...
# 88864  Another engineering discipline (ex. civil, ele...
# 88865  A humanities discipline (ex. literature, histo...
# 88866  Computer science, computer engineering, or sof...
# 88867                                                NaN
# 88868                                                NaN
# 88869                                                NaN
# 88870  Computer science, computer engineering, or sof...
# 88871  Computer science, computer engineering, or sof...
# 88872  Computer science, computer engineering, or sof...
# 88873                                                NaN
# 88874                                                NaN
# 88875                                                NaN
# 88876                                                NaN
# 88877  Computer science, computer engineering, or sof...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# 5      Taken an online course in programming or softw...
# 6      Taught yourself a new language, framework, or ...
# 7      Taught yourself a new language, framework, or ...
# 8      Taken an online course in programming or softw...
# 9                                                    NaN
# 10                   Contributed to open source software
# 11     Taken an online course in programming or softw...
# 12     Taken an online course in programming or softw...
# 13     Completed an industry certification program (e...
# 14     Taken an online course in programming or softw...
# 15     Taken an online course in programming or softw...
# 16     Taken an online course in programming or softw...
# 17     Taken an online course in programming or softw...
# 18     Received on-the-job training in software devel...
# 19     Taken an online course in programming or softw...
# 20     Taught yourself a new language, framework, or ...
# 21     Taken an online course in programming or softw...
# 22     Taken an online course in programming or softw...
# 23     Taken an online course in programming or softw...
# 24     Taken an online course in programming or softw...
# 25     Taught yourself a new language, framework, or ...
# 26     Taken an online course in programming or softw...
# 27     Taken an online course in programming or softw...
# 28     Taken an online course in programming or softw...
# 29     Taught yourself a new language, framework, or ...
# 30                                                   NaN
# 31     Completed an industry certification program (e...
# 32     Taken an online course in programming or softw...
# 33     Taken an online course in programming or softw...
# 34     Taken a part-time in-person course in programm...
# 35     Taken an online course in programming or softw...
# 36     Taken a part-time in-person course in programm...
# 37     Participated in a full-time developer training...
# 38     Taken an online course in programming or softw...
# 39     Taken an online course in programming or softw...
# 40     Taken an online course in programming or softw...
# 41     Taken a part-time in-person course in programm...
# ...                                                  ...
# 88841  Taken an online course in programming or softw...
# 88842  Taken an online course in programming or softw...
# 88843  Taken an online course in programming or softw...
# 88844  Taken an online course in programming or softw...
# 88845                                                NaN
# 88846                                                NaN
# 88847                                                NaN
# 88848  Taken an online course in programming or softw...
# 88849                                                NaN
# 88850  Taught yourself a new language, framework, or ...
# 88851                                                NaN
# 88852                        Participated in a hackathon
# 88853  Taken an online course in programming or softw...
# 88854  Taken an online course in programming or softw...
# 88855                                                NaN
# 88856                                                NaN
# 88857  Taken an online course in programming or softw...
# 88858                                                NaN
# 88859  Taken an online course in programming or softw...
# 88860  Taught yourself a new language, framework, or ...
# 88861                                                NaN
# 88862  Taught yourself a new language, framework, or ...
# 88863  Taught yourself a new language, framework, or ...
# 88864  Taught yourself a new language, framework, or ...
# 88865  Taken a part-time in-person course in programm...
# 88866                                                NaN
# 88867                Contributed to open source software
# 88868                                                NaN
# 88869                                                NaN
# 88870                                                NaN
# 88871  Taken an online course in programming or softw...
# 88872  Taught yourself a new language, framework, or ...
# 88873                                                NaN
# 88874                                                NaN
# 88875  Taken an online course in programming or softw...
# 88876  Taught yourself a new language, framework, or ...
# 88877  Taught yourself a new language, framework, or ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                                                  OrgSize  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   100 to 499 employees
# 3                                   100 to 499 employees
# 4                               10,000 or more employees
# 5                                                    NaN
# 6      Just me - I am a freelancer, sole proprietor, ...
# 7                                                    NaN
# 8                                     10 to 19 employees
# 9                               10,000 or more employees
# 10                                                   NaN
# 11                                                   NaN
# 12                                    10 to 19 employees
# 13                                  100 to 499 employees
# 14                                                   NaN
# 15                                  100 to 499 employees
# 16                                    20 to 99 employees
# 17                              1,000 to 4,999 employees
# 18                                  100 to 499 employees
# 19                              1,000 to 4,999 employees
# 20                                                   NaN
# 21                              10,000 or more employees
# 22                              10,000 or more employees
# 23                                    10 to 19 employees
# 24                                         2-9 employees
# 25                              10,000 or more employees
# 26                                                   NaN
# 27                                         2-9 employees
# 28                              10,000 or more employees
# 29                              1,000 to 4,999 employees
# 30                                                   NaN
# 31                                  100 to 499 employees
# 32                              10,000 or more employees
# 33                                                   NaN
# 34                                    20 to 99 employees
# 35                              1,000 to 4,999 employees
# 36                                  100 to 499 employees
# 37                                    10 to 19 employees
# 38                                  100 to 499 employees
# 39                                                   NaN
# 40                                         2-9 employees
# 41     Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 88841                                                NaN
# 88842  Just me - I am a freelancer, sole proprietor, ...
# 88843                               100 to 499 employees
# 88844                                                NaN
# 88845                                                NaN
# 88846                                                NaN
# 88847                                                NaN
# 88848                                                NaN
# 88849                                                NaN
# 88850                               500 to 999 employees
# 88851                                                NaN
# 88852                                                NaN
# 88853                               100 to 499 employees
# 88854                           1,000 to 4,999 employees
# 88855                                                NaN
# 88856                                                NaN
# 88857                               100 to 499 employees
# 88858                                                NaN
# 88859  Just me - I am a freelancer, sole proprietor, ...
# 88860                                                NaN
# 88861                                                NaN
# 88862                                                NaN
# 88863                                                NaN
# 88864                               100 to 499 employees
# 88865                                                NaN
# 88866                                                NaN
# 88867  Just me - I am a freelancer, sole proprietor, ...
# 88868                                                NaN
# 88869                                                NaN
# 88870                                                NaN
# 88871                                                NaN
# 88872                               500 to 999 employees
# 88873                                                NaN
# 88874                                                NaN
# 88875                                 10 to 19 employees
# 88876                                 10 to 19 employees
# 88877                                                NaN
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                                  DevType           YearsCode  \
# 0                                                    NaN                   4
# 1      Developer, desktop or enterprise applications;...                 NaN
# 2      Designer;Developer, back-end;Developer, front-...                   3
# 3                                  Developer, full-stack                   3
# 4      Academic researcher;Developer, desktop or ente...                  16
# 5      Data or business analyst;Data scientist or mac...                  13
# 6                          Designer;Developer, front-end                   6
# ...
# 3                              Straight / Heterosexual
# 4                              Straight / Heterosexual
# 5                              Straight / Heterosexual
# 6                              Straight / Heterosexual
# 7                              Straight / Heterosexual
# 8                                             Bisexual
# 9                                                  NaN
# 10     Bisexual;Gay or Lesbian;Straight / Heterosexual
# 11                             Straight / Heterosexual
# 12                             Straight / Heterosexual
# 13                             Straight / Heterosexual
# 14                                                 NaN
# 15                             Straight / Heterosexual
# 16                             Straight / Heterosexual
# 17                             Straight / Heterosexual
# 18                             Straight / Heterosexual
# 19                             Straight / Heterosexual
# 20                                                 NaN
# 21                             Straight / Heterosexual
# 22                             Straight / Heterosexual
# 23                             Straight / Heterosexual
# 24                             Straight / Heterosexual
# 25                                      Gay or Lesbian
# 26                             Straight / Heterosexual
# 27                                                 NaN
# 28                             Straight / Heterosexual
# 29                             Straight / Heterosexual
# 30                                                 NaN
# 31                             Straight / Heterosexual
# 32                             Straight / Heterosexual
# 33                                            Bisexual
# 34                             Straight / Heterosexual
# 35                             Straight / Heterosexual
# 36                                                 NaN
# 37                                                 NaN
# 38                                            Bisexual
# 39                             Bisexual;Gay or Lesbian
# 40                                                 NaN
# 41                             Straight / Heterosexual
# ...                                                ...
# 88841                          Straight / Heterosexual
# 88842                          Straight / Heterosexual
# 88843                          Straight / Heterosexual
# 88844                                         Bisexual
# 88845                                              NaN
# 88846                                   Gay or Lesbian
# 88847                                              NaN
# 88848                                              NaN
# 88849                                              NaN
# 88850                                              NaN
# 88851                                              NaN
# 88852                          Straight / Heterosexual
# 88853                                              NaN
# 88854                                         Bisexual
# 88855                          Straight / Heterosexual
# 88856                                              NaN
# 88857                          Straight / Heterosexual
# 88858                                              NaN
# 88859                          Bisexual;Gay or Lesbian
# 88860                          Straight / Heterosexual
# 88861                                              NaN
# 88862                                              NaN
# 88863                                   Gay or Lesbian
# 88864                                              NaN
# 88865                                              NaN
# 88866                          Straight / Heterosexual
# 88867                                              NaN
# 88868                                              NaN
# 88869                                              NaN
# 88870                                              NaN
# 88871                          Straight / Heterosexual
# 88872                          Straight / Heterosexual
# 88873                                              NaN
# 88874                                              NaN
# 88875                          Straight / Heterosexual
# 88876                          Straight / Heterosexual
# 88877                          Straight / Heterosexual
# 88878                                              NaN
# 88879                                              NaN
# 88880                                              NaN
# 88881                                              NaN
# 88882                          Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# 5                                             East Asian         No
# 6                           White or of European descent        Yes
# 7                                                    NaN        NaN
# 8                           White or of European descent         No
# 9                                                    NaN        Yes
# 10     Black or of African descent;East Asian;Hispani...         No
# 11                           Black or of African descent         No
# 12                          White or of European descent        Yes
# 13                          White or of European descent         No
# 14                                                   NaN        Yes
# 15                          White or of European descent         No
# 16                 Hispanic or Latino/Latina;Multiracial         No
# 17                          White or of European descent        Yes
# 18                             Hispanic or Latino/Latina        Yes
# 19                          White or of European descent        Yes
# 20                                                   NaN         No
# 21                          White or of European descent        Yes
# 22                           Black or of African descent         No
# 23                                        Middle Eastern         No
# 24                          White or of European descent         No
# 25                                                   NaN         No
# 26                             Hispanic or Latino/Latina         No
# 27                                                   NaN        NaN
# 28                          White or of European descent        Yes
# 29                          White or of European descent         No
# 30                                            East Asian         No
# 31                          White or of European descent         No
# 32                             Hispanic or Latino/Latina         No
# 33                                           South Asian        Yes
# 34                           Black or of African descent         No
# 35                          White or of European descent         No
# 36                          White or of European descent         No
# 37                                                   NaN        Yes
# 38                          White or of European descent         No
# 39                          White or of European descent         No
# 40                                                   NaN        NaN
# 41                                        Middle Eastern        NaN
# ...                                                  ...        ...
# 88841              White or of European descent;Biracial         No
# 88842                       White or of European descent        Yes
# 88843                                                NaN        Yes
# 88844                       White or of European descent         No
# 88845                                                NaN        NaN
# 88846                                                NaN        NaN
# 88847                                                NaN        NaN
# 88848                                                NaN         No
# 88849                                                NaN        NaN
# 88850                       White or of European descent        Yes
# 88851                                                NaN        NaN
# 88852                                                NaN        Yes
# 88853                                                NaN        NaN
# 88854                       White or of European descent         No
# 88855                                                NaN         No
# 88856                                                NaN        NaN
# 88857                        Black or of African descent        NaN
# 88858                                                NaN        NaN
# 88859                       White or of European descent         No
# 88860  Hispanic or Latino/Latina;White or of European...         No
# 88861                                                NaN        NaN
# 88862                                     Middle Eastern         No
# 88863                       White or of European descent         No
# 88864                                        South Asian        NaN
# 88865                       White or of European descent         No
# 88866                       White or of European descent        Yes
# 88867         Black or of African descent;Middle Eastern         No
# 88868                                                NaN        NaN
# 88869                                                NaN        NaN
# 88870                                                NaN         No
# 88871                       White or of European descent         No
# 88872                       White or of European descent         No
# 88873                                                NaN        NaN
# 88874                                                NaN        NaN
# 88875                                                NaN        Yes
# 88876                       White or of European descent         No
# 88877                                                NaN         No
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# 5                   Too long  Neither easy nor difficult
# 6      Appropriate in length  Neither easy nor difficult
# 7      Appropriate in length  Neither easy nor difficult
# 8      Appropriate in length  Neither easy nor difficult
# 9                   Too long                   Difficult
# 10     Appropriate in length                        Easy
# 11     Appropriate in length                        Easy
# 12     Appropriate in length                        Easy
# 13                 Too short                        Easy
# 14                  Too long  Neither easy nor difficult
# 15     Appropriate in length  Neither easy nor difficult
# 16     Appropriate in length                        Easy
# 17     Appropriate in length  Neither easy nor difficult
# 18                  Too long                        Easy
# 19     Appropriate in length                        Easy
# 20     Appropriate in length                        Easy
# 21     Appropriate in length                        Easy
# 22     Appropriate in length                        Easy
# 23     Appropriate in length                        Easy
# 24                 Too short  Neither easy nor difficult
# 25     Appropriate in length                        Easy
# 26     Appropriate in length  Neither easy nor difficult
# 27                       NaN                         NaN
# 28     Appropriate in length                        Easy
# 29                  Too long                        Easy
# 30                  Too long  Neither easy nor difficult
# 31     Appropriate in length  Neither easy nor difficult
# 32     Appropriate in length  Neither easy nor difficult
# 33                 Too short  Neither easy nor difficult
# 34     Appropriate in length                        Easy
# 35                  Too long  Neither easy nor difficult
# 36     Appropriate in length  Neither easy nor difficult
# 37     Appropriate in length  Neither easy nor difficult
# 38     Appropriate in length                        Easy
# 39     Appropriate in length                        Easy
# 40                  Too long  Neither easy nor difficult
# 41     Appropriate in length                        Easy
# ...                      ...                         ...
# 88841  Appropriate in length                        Easy
# 88842  Appropriate in length  Neither easy nor difficult
# 88843  Appropriate in length  Neither easy nor difficult
# 88844  Appropriate in length                        Easy
# 88845                    NaN                         NaN
# 88846                    NaN                         NaN
# 88847                    NaN                         NaN
# 88848  Appropriate in length  Neither easy nor difficult
# 88849                    NaN                         NaN
# 88850               Too long  Neither easy nor difficult
# 88851                    NaN                         NaN
# 88852               Too long  Neither easy nor difficult
# 88853                    NaN                         NaN
# 88854  Appropriate in length                        Easy
# 88855               Too long                        Easy
# 88856                    NaN                         NaN
# 88857               Too long  Neither easy nor difficult
# 88858                    NaN                         NaN
# 88859  Appropriate in length                        Easy
# 88860              Too short                        Easy
# 88861                    NaN                         NaN
# 88862               Too long  Neither easy nor difficult
# 88863  Appropriate in length                   Difficult
# 88864  Appropriate in length                        Easy
# 88865  Appropriate in length                        Easy
# 88866  Appropriate in length                        Easy
# 88867  Appropriate in length  Neither easy nor difficult
# 88868                    NaN                         NaN
# 88869                    NaN                         NaN
# 88870                    NaN                         NaN
# 88871  Appropriate in length                        Easy
# 88872  Appropriate in length                        Easy
# 88873                    NaN                         NaN
# 88874                    NaN                         NaN
# 88875              Too short  Neither easy nor difficult
# 88876  Appropriate in length                        Easy
# 88877              Too short  Neither easy nor difficult
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
schema_df.set_index('Column',inplace=True)
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# Country                         In which country do you currently reside?
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear  Which of the following database environments h...
# DatabaseWorkedWith      Which of the following database environments h...
# Dependents              Do you have any dependents (e.g., children, el...
# DevEnviron              Which development environment(s) do you use re...
# DevType                 Which of the following describe you? Please se...
# EdLevel                 Which of the following best describes the high...
# EduOther                Which of the following types of non-degree edu...
# Employment              Which of the following best describes your cur...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# Ethnicity               Which of the following do you identify as? Ple...
# Extraversion              Do you prefer online chat or IRL conversations?
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# Gender                  Which of the following do you currently identi...
# Hobbyist                                          Do you code as a hobby?
# ITperson                 Are you the "IT support person" for your family?
# ImpSyn                  For the specific work you do, and the years of...
# JobFactors              Imagine that you are deciding between two job ...
# JobSat                  How satisfied are you with your current job? (...
# JobSeek                 Which of the following best describes your cur...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# MainBranch              Which of the following options best describes ...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# OffOn                         Have you tried turning it off and on again?
# OpSys                   What is the primary operating system in which ...
# OpenSource              How do you feel about the quality of open sour...
# OpenSourcer                   How often do you contribute to open source?
# OrgSize                 Approximately how many people are employed by ...
# PlatformDesireNextYear  Which of the following platforms have you done...
# PlatformWorkedWith      Which of the following platforms have you done...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# Respondent              Randomized respondent ID number (not in order ...
# ResumeUpdate            Think back to the last time you updated your r...
# SOAccount                           Do you have a Stack Overflow account?
# SOComm                  Do you consider yourself a member of the Stack...
# SOFindAnswer            On average, how many times a week do you find ...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# SONewContent            Would you like to see any of the following on ...
# SOPartFreq              How frequently would you say you participate i...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# ScreenName                                           What do you call it?
# Sexuality               Which of the following do you currently identi...
# SocialMedia                   What social media site do you use the most?
# Student                 Are you currently enrolled in a formal, degree...
# SurveyEase              How easy or difficult was this survey to compl...
# SurveyLength            How do you feel about the length of the survey...
# Trans                                     Do you identify as transgender?
# UndergradMajor          What was your main or most important field of ...
# UnitTests               Does your company regularly employ unit tests ...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WorkChallenge           Of these options, what are your greatest chall...
# WorkLoc                                   Where would you prefer to work?
# WorkPlan                          How structured or planned is your work?
# WorkRemote                                How often do you work remotely?
# WorkWeekHrs              On average, how many hours per week do you work?
# YearsCode               Including any education, how many years have y...
# YearsCodePro            How many years have you coded professionally (...

# %%
high_sal = df['ConvertedComp'] > 70000
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df.loc[high_sal, ['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 25      United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 28      United States               Bash/Shell/PowerShell;JavaScript;SQL
# 29        Switzerland                                                NaN
# 31      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 34      United States                                HTML/CSS;JavaScript
# 38      United States                       C#;JavaScript;SQL;TypeScript
# 43            Germany  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 44      United States                                             Python
# 46      United States                                      Java;PHP;Ruby
# 56             France                                  JavaScript;Python
# 57      United States                                        C#;Java;SQL
# 59      United States  Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# 61        Netherlands  Bash/Shell/PowerShell;C++;Go;HTML/CSS;Java;Jav...
# 65            Germany          Clojure;Go;HTML/CSS;Java;JavaScript;R;SQL
# 69      United States                         C#;HTML/CSS;JavaScript;SQL
# 71        New Zealand          C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 73            Ireland        HTML/CSS;Java;JavaScript;Kotlin;Python;Ruby
# 76      United States                        HTML/CSS;JavaScript;PHP;SQL
# 81     United Kingdom  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 82              India                                HTML/CSS;JavaScript
# 94      United States                C#;HTML/CSS;JavaScript;Python;R;SQL
# 99             Canada            HTML/CSS;JavaScript;Ruby;SQL;TypeScript
# 101     United States              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 105     United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 107     United States                                         C++;Python
# 109     United States                                         Python;SQL
# 115             Spain                                    Scala;Other(s):
# 124       Netherlands  Bash/Shell/PowerShell;Dart;HTML/CSS;Java;JavaS...
# 126     United States                     Bash/Shell/PowerShell;C;Python
# 127    United Kingdom                      Bash/Shell/PowerShell;Go;Ruby
# 130         Australia                                               Java
# 131     United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;Java;Jav...
# 140     United States                           Bash/Shell/PowerShell;C#
# 141           Germany   C;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 146     United States                     HTML/CSS;JavaScript;TypeScript
# 150           Finland  HTML/CSS;Java;JavaScript;Kotlin;Objective-C;Py...
# 151         Australia                                       C;C++;Python
# ...               ...                                                ...
# 88167       Lithuania  Bash/Shell/PowerShell;C;HTML/CSS;Java;JavaScri...
# 88169   United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;K...
# 88176        Slovakia                       Bash/Shell/PowerShell;Python
# 88183   United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 88187           Italy              Bash/Shell/PowerShell;Java;Kotlin;SQL
# 88192   United States                       HTML/CSS;Java;JavaScript;SQL
# 88198          Canada                   C;C++;Python;Scala;SQL;Other(s):
# 88199   United States  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 88201         Germany            Bash/Shell/PowerShell;C++;C#;PHP;Python
# 88204     Switzerland           Bash/Shell/PowerShell;Go;Java;Python;SQL
# 88208   United States        Bash/Shell/PowerShell;Java;Python;Scala;SQL
# 88212   United States               Bash/Shell/PowerShell;C;HTML/CSS;SQL
# 88214   United States                                    Assembly;C;Rust
# 88217           India                                        C++;Go;Java
# 88221          Canada       Bash/Shell/PowerShell;C#;Java;PHP;Python;SQL
# 88227   United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 88228     New Zealand   Bash/Shell/PowerShell;Erlang;HTML/CSS;JavaScript
# 88244   United States               Bash/Shell/PowerShell;Go;Python;Ruby
# 88246   United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 88249          Sweden                                            C#;Rust
# 88264   United States         HTML/CSS;Java;JavaScript;Kotlin;Python;SQL
# 88266   United States              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 88275   United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;SQL;...
# 88281  United Kingdom                          HTML/CSS;JavaScript;Scala
# 88282   United States                                       C;Python;SQL
# 88283   United States          Bash/Shell/PowerShell;Java;JavaScript;SQL
# 88287   United States       HTML/CSS;JavaScript;PHP;Python;SQL;Other(s):
# 88290   United States               Clojure;HTML/CSS;Java;JavaScript;SQL
# 88298   United States                       HTML/CSS;Java;JavaScript;SQL
# 88301   United States   Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL
# 88303   United States                       HTML/CSS;Java;JavaScript;SQL
# 88309         Germany              Go;HTML/CSS;JavaScript;PHP;Python;SQL
# 88312   United States                                HTML/CSS;JavaScript
# 88314        Portugal            Bash/Shell/PowerShell;JavaScript;Python
# 88315         Germany                 HTML/CSS;JavaScript;PHP;TypeScript
# 88320          Canada               HTML/CSS;JavaScript;PHP;Python;R;SQL
# 88321   United States                               C++;Python;Scala;SQL
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# 15          455352.0
# 21          103000.0
# 25          114000.0
# 28          100000.0
# 29           90417.0
# 31         1100000.0
# 34           80000.0
# 38          156000.0
# 43           87996.0
# 44          175000.0
# 46          187000.0
# 56           97389.0
# 57         2000000.0
# 59          107000.0
# 61           87994.0
# 65          137490.0
# 69           75000.0
# 71          110352.0
# 73          114575.0
# 76          100000.0
# 81          143932.0
# 82          117540.0
# 94          110000.0
# 99          229016.0
# 101        2000000.0
# 105         160000.0
# 107         140000.0
# 109         100000.0
# 115         103117.0
# 124         194800.0
# 126         106000.0
# 127        1000000.0
# 130         199450.0
# 131          83200.0
# 140         180000.0
# 141          93951.0
# 146         135000.0
# 150         103117.0
# 151          87036.0
# ...              ...
# 88167        70116.0
# 88169        82625.0
# 88176        89364.0
# 88183       120000.0
# 88187        80202.0
# 88192        95000.0
# 88198        87789.0
# 88199        71000.0
# 88201        91660.0
# 88204      1000000.0
# 88208       124000.0
# 88212        80000.0
# 88214       120000.0
# 88217       235080.0
# 88221       120000.0
# 88227        79500.0
# 88228        96558.0
# 88244       225000.0
# 88246       105000.0
# 88249        72912.0
# 88264      2000000.0
# 88266      2000000.0
# 88275       110000.0
# 88281       204100.0
# 88282       120000.0
# 88283       230000.0
# 88287        95000.0
# 88290       111000.0
# 88298       120000.0
# 88301       110000.0
# 88303        80000.0
# 88309        97389.0
# 88312       120000.0
# 88314       412464.0
# 88315       797436.0
# 88320        72522.0
# 88321      2000000.0
# 88323       180000.0
# 88324      2000000.0
# 88325       130000.0
# 88326        82488.0
# 88329       588012.0
#
# [22289 rows x 3 columns]

# %%
countries=['United States','India','United Kingdom','Germany','Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, ['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 0      United Kingdom                    HTML/CSS;Java;JavaScript;Python
# 3       United States                                C;C++;C#;Python;SQL
# 5              Canada                                         Java;R;SQL
# 7               India  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9               India                      C#;Go;JavaScript;Python;R;SQL
# 11             Canada   Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 13            Germany                                                C++
# 14              India  Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 20             Canada  Assembly;Bash/Shell/PowerShell;C;C++;Go;Java;J...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 22      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 25      United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 28      United States               Bash/Shell/PowerShell;JavaScript;SQL
# 30             Canada                                             Python
# 31      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 34      United States                                HTML/CSS;JavaScript
# 35            Germany                                 Java;Kotlin;Python
# 36             Canada  Bash/Shell/PowerShell;JavaScript;Python;Other(s):
# 38      United States                       C#;JavaScript;SQL;TypeScript
# 43            Germany  Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 44      United States                                             Python
# 45      United States  Bash/Shell/PowerShell;C;C#;HTML/CSS;JavaScript...
# 46      United States                                      Java;PHP;Ruby
# 49              India  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 50      United States  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 52      United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 57      United States                                        C#;Java;SQL
# 59      United States  Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# 60      United States      C++;C#;HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 64              India                    Assembly;C;C++;C#;HTML/CSS;Java
# 65            Germany          Clojure;Go;HTML/CSS;Java;JavaScript;R;SQL
# 67              India                    HTML/CSS;Java;JavaScript;Python
# 69      United States                         C#;HTML/CSS;JavaScript;SQL
# 74              India                                HTML/CSS;JavaScript
# 75     United Kingdom                                            PHP;SQL
# 76      United States                        HTML/CSS;JavaScript;PHP;SQL
# 77              India             HTML/CSS;Java;JavaScript;Kotlin;Python
# 78             Canada                  C#;HTML/CSS;JavaScript;TypeScript
# 79     United Kingdom  Bash/Shell/PowerShell;C#;F#;Go;HTML/CSS;Java;J...
# 81     United Kingdom  Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# ...               ...                                                ...
# 88756  United Kingdom                                              C#;Go
# 88757   United States                                                NaN
# 88758   United States                             C;HTML/CSS;Java;Python
# 88759          Canada                       Assembly;Java;JavaScript;SQL
# 88760   United States                    Bash/Shell/PowerShell;C++;Swift
# 88761  United Kingdom                                                NaN
# 88764   United States  Bash/Shell/PowerShell;C;JavaScript;PHP;Python;...
# 88771          Canada                              C;C++;HTML/CSS;Python
# 88773   United States                                                NaN
# 88777   United States                                HTML/CSS;JavaScript
# 88779         Germany                                          Other(s):
# 88783           India  Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88786   United States                   HTML/CSS;JavaScript;Python;Swift
# 88794  United Kingdom                                                NaN
# 88797   United States                                                C++
# 88798           India                                           Java;VBA
# 88801          Canada                    Bash/Shell/PowerShell;Go;Python
# 88804         Germany  Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Swif...
# 88806           India  Assembly;C++;HTML/CSS;JavaScript;PHP;SQL;Other...
# 88808           India                                          Other(s):
# 88810   United States                                                NaN
# 88811   United States  Bash/Shell/PowerShell;C;C++;HTML/CSS;JavaScrip...
# 88818   United States                     Bash/Shell/PowerShell;C;Python
# 88820  United Kingdom  Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88825           India               Bash/Shell/PowerShell;Python;SQL;VBA
# 88826  United Kingdom                         HTML/CSS;JavaScript;Python
# 88828  United Kingdom                                 HTML/CSS;Java;Ruby
# 88829         Germany  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 88838          Canada        Assembly;Java;JavaScript;Objective-C;Python
# 88840   United States                                                NaN
# 88841  United Kingdom  Bash/Shell/PowerShell;C++;C#;HTML/CSS;Python;Ruby
# 88844   United States                     HTML/CSS;JavaScript;Python;SQL
# 88850         Germany              HTML/CSS;JavaScript;Kotlin;TypeScript
# 88852           India  Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 88853           India   HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 88854  United Kingdom  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88855          Canada                                               Dart
# 88859   United States                                        Go;HTML/CSS
# 88863  United Kingdom                                    C;C++;Other(s):
# 88864           India      Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# 88877   United States  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88878          Canada                      HTML/CSS;JavaScript;Other(s):
#
#        ConvertedComp
# 0                NaN
# 3            61000.0
# 5           366420.0
# 7                NaN
# 9            13293.0
# 11               NaN
# 12           90000.0
# 13           57060.0
# 14               NaN
# 15          455352.0
# 20               NaN
# 21          103000.0
# 22           69000.0
# 25          114000.0
# 28          100000.0
# 30               NaN
# 31         1100000.0
# 34           80000.0
# 35           20628.0
# 36               NaN
# 38          156000.0
# 43           87996.0
# 44          175000.0
# 45               NaN
# 46          187000.0
# 49            5597.0
# 50               NaN
# 52           47300.0
# 57         2000000.0
# 59          107000.0
# 60           66000.0
# 64               NaN
# 65          137490.0
# 67           11194.0
# 69           75000.0
# 74           17491.0
# 75           39254.0
# 76          100000.0
# 77            7696.0
# 78               NaN
# 79               NaN
# 81          143932.0
# ...              ...
# 88756            NaN
# 88757            NaN
# 88758            NaN
# 88759            NaN
# 88760            NaN
# 88761            NaN
# 88764            NaN
# 88771            NaN
# 88773            NaN
# 88777            NaN
# 88779            NaN
# 88783            NaN
# 88786            NaN
# 88794            NaN
# 88797            NaN
# 88798            NaN
# 88801            NaN
# 88804            NaN
# 88806            NaN
# 88808            NaN
# 88810            NaN
# 88811            NaN
# 88818            NaN
# 88820            NaN
# 88825            NaN
# 88826            NaN
# 88828            NaN
# 88829            NaN
# 88838            NaN
# 88840            NaN
# 88841            NaN
# 88844            NaN
# 88850            NaN
# 88852            NaN
# 88853            NaN
# 88854            NaN
# 88855            NaN
# 88859            NaN
# 88863            NaN
# 88864            NaN
# 88877            NaN
# 88878            NaN
#
# [45008 rows x 3 columns]

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 5                                               Java;R;SQL
# 6                                      HTML/CSS;JavaScript
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 8        Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 9                            C#;Go;JavaScript;Python;R;SQL
# 10                                               Other(s):
# 11        Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 12       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 13                                                     C++
# 14       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 15       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 16       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Type...
# 17                                                Python;R
# 18              C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 19       Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 20       Assembly;Bash/Shell/PowerShell;C;C++;Go;Java;J...
# 21       Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 22       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 23                      HTML/CSS;JavaScript;PHP;TypeScript
# 24                  HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 25       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 26               C++;JavaScript;Python;Ruby;SQL;TypeScript
# 27                                   JavaScript;TypeScript
# 28                    Bash/Shell/PowerShell;JavaScript;SQL
# 29                                                     NaN
# 30                                                  Python
# 31       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 32                                            C++;Python;R
# 33                                     HTML/CSS;JavaScript
# 34                                     HTML/CSS;JavaScript
# 35                                      Java;Kotlin;Python
# 36       Bash/Shell/PowerShell;JavaScript;Python;Other(s):
# 37                              C#;HTML/CSS;JavaScript;SQL
# 38                            C#;JavaScript;SQL;TypeScript
# 39                                             C#;HTML/CSS
# 40       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 41                      HTML/CSS;JavaScript;PHP;TypeScript
#                                ...
# 88841    Bash/Shell/PowerShell;C++;C#;HTML/CSS;Python;Ruby
# 88842                                                  NaN
# 88843                                Bash/Shell/PowerShell
# 88844                       HTML/CSS;JavaScript;Python;SQL
# 88845                                                  NaN
# 88846                                                  NaN
# 88847                                                  NaN
# 88848    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 88849                                                  NaN
# 88850                HTML/CSS;JavaScript;Kotlin;TypeScript
# 88851                                                  NaN
# 88852    Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 88853     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88855                                                 Dart
# 88856                                                  NaN
# 88857             Bash/Shell/PowerShell;HTML/CSS;PHP;R;SQL
# 88858                                                  NaN
# 88859                                          Go;HTML/CSS
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88861                                                  NaN
# 88862                                                  NaN
# 88863                                      C;C++;Other(s):
# 88864        Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88866                            Assembly;C++;HTML/CSS;VBA
# 88867                                                  NaN
# 88868                                                  NaN
# 88869                                                  NaN
# 88870                                           C;C++;Java
# 88871    Assembly;Bash/Shell/PowerShell;C;C#;HTML/CSS;J...
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88873                                                  NaN
# 88874                                                  NaN
# 88875                             HTML/CSS;Java;JavaScript
# 88876                           HTML/CSS;JavaScript;Python
# 88877    Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 11             12             I am a student who is learning to code       No
# 17             18  I am not primarily a developer, but I write co...      Yes
# 19             20  I am not primarily a developer, but I write co...       No
# 20             21                        I code primarily as a hobby      Yes
# 21             22                     I am a developer by profession      Yes
# 22             23                     I am a developer by profession      Yes
# 25             26                     I am a developer by profession      Yes
# 26             27  I used to be a developer by profession, but no...      Yes
# 30             31             I am a student who is learning to code       No
# 31             32                     I am a developer by profession       No
# 32             33                     I am a developer by profession       No
# 35             36                     I am a developer by profession      Yes
# 36             37                        I code primarily as a hobby      Yes
# 44             45  I am not primarily a developer, but I write co...      Yes
# 45             46                     I am a developer by profession      Yes
# 48             49                     I am a developer by profession      Yes
# 49             50                     I am a developer by profession      Yes
# 50             51             I am a student who is learning to code      Yes
# 51             52                     I am a developer by profession      Yes
# 53             54                     I am a developer by profession      Yes
# 54             55             I am a student who is learning to code      Yes
# 56             57  I am not primarily a developer, but I write co...      Yes
# 59             60                     I am a developer by profession      Yes
# 60             61                     I am a developer by profession      Yes
# 61             62                     I am a developer by profession      Yes
# 62             63                     I am a developer by profession      Yes
# 66             67  I am not primarily a developer, but I write co...       No
# 67             68                     I am a developer by profession      Yes
# 70             71                     I am a developer by profession      Yes
# 73             74                     I am a developer by profession      Yes
# 77             78                     I am a developer by profession       No
# 79             80                     I am a developer by profession      Yes
# 80             81                     I am a developer by profession      Yes
# 81             82                     I am a developer by profession      Yes
# 84             85                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88722       61753                                                NaN       No
# 88724       61787                                                NaN      Yes
# 88725       61922                                                NaN      Yes
# 88728       62177                                                NaN      Yes
# 88734       62999                                                NaN      Yes
# 88736       63462                                                NaN       No
# 88744       64998                                                NaN      Yes
# 88745       65265                                                NaN      Yes
# 88746       65296                                                NaN       No
# 88751       66751                                                NaN      Yes
# 88754       66972                                                NaN      Yes
# 88758       67206                                                NaN      Yes
# 88764       68208                                                NaN      Yes
# 88767       68525                                                NaN      Yes
# 88770       69366                                                NaN       No
# 88771       69741                                                NaN      Yes
# 88774       70630                                                NaN       No
# 88776       70746                                                NaN      Yes
# 88778       70985                                                NaN      Yes
# 88780       71160                                                NaN      Yes
# 88783       71874                                                NaN      Yes
# 88786       72325                                                NaN      Yes
# 88787       72492                                                NaN      Yes
# 88801       75496                                                NaN      Yes
# 88804       75974                                                NaN      Yes
# 88813       77968                                                NaN       No
# 88818       78292                                                NaN       No
# 88820       78741                                                NaN      Yes
# 88825       79795                                                NaN      Yes
# 88826       79798                                                NaN      Yes
# 88836       81934                                                NaN      Yes
# 88837       81994                                                NaN      Yes
# 88838       82007                                                NaN       No
# 88841       82789                                                NaN      Yes
# 88844       83397                                                NaN      Yes
# 88848       83709                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88854       84539                                                NaN      Yes
# 88860       85738                                                NaN      Yes
# 88865       86566                                                NaN      Yes
# 88872       87739                                                NaN      Yes
# 88876       88212                                                NaN       No
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 3                                                  Never
# 4                             Once a month or more often
# 7                                Less than once per year
# 8                             Once a month or more often
# 9                             Once a month or more often
# 11                                                 Never
# 17     Less than once a month but more than once per ...
# 19                                                 Never
# 20                            Once a month or more often
# 21                               Less than once per year
# 22                               Less than once per year
# 25                               Less than once per year
# 26                               Less than once per year
# 30                                                 Never
# 31                                                 Never
# 32     Less than once a month but more than once per ...
# 35     Less than once a month but more than once per ...
# 36                               Less than once per year
# 44                                                 Never
# 45                               Less than once per year
# 48                               Less than once per year
# 49                            Once a month or more often
# 50                                                 Never
# 51                            Once a month or more often
# 53                            Once a month or more often
# 54     Less than once a month but more than once per ...
# 56                                                 Never
# 59     Less than once a month but more than once per ...
# 60                               Less than once per year
# 61     Less than once a month but more than once per ...
# 62     Less than once a month but more than once per ...
# 66                                                 Never
# 67     Less than once a month but more than once per ...
# 70                                                 Never
# 73                                                 Never
# 77     Less than once a month but more than once per ...
# 79     Less than once a month but more than once per ...
# 80     Less than once a month but more than once per ...
# 81                            Once a month or more often
# 84                                                 Never
# ...                                                  ...
# 88722                            Less than once per year
# 88724                            Less than once per year
# 88725                            Less than once per year
# 88728                            Less than once per year
# 88734                                              Never
# 88736                         Once a month or more often
# 88744                            Less than once per year
# 88745                         Once a month or more often
# 88746                            Less than once per year
# 88751  Less than once a month but more than once per ...
# 88754                         Once a month or more often
# 88758                         Once a month or more often
# 88764                            Less than once per year
# 88767                            Less than once per year
# 88770                            Less than once per year
# 88771                         Once a month or more often
# 88774  Less than once a month but more than once per ...
# 88776                                              Never
# 88778                                              Never
# 88780  Less than once a month but more than once per ...
# 88783                                              Never
# 88786                         Once a month or more often
# 88787                         Once a month or more often
# 88801                            Less than once per year
# 88804                         Once a month or more often
# 88813                            Less than once per year
# 88818                         Once a month or more often
# 88820                                              Never
# 88825  Less than once a month but more than once per ...
# 88826  Less than once a month but more than once per ...
# 88836  Less than once a month but more than once per ...
# 88837                                              Never
# 88838                            Less than once per year
# 88841                         Once a month or more often
# 88844                            Less than once per year
# 88848                         Once a month or more often
# 88853                                              Never
# 88854  Less than once a month but more than once per ...
# 88860                                              Never
# 88865  Less than once a month but more than once per ...
# 88872                            Less than once per year
# 88876                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# 7      OSS is, on average, of HIGHER quality than pro...
# 8      The quality of OSS and closed source software ...
# 9      OSS is, on average, of HIGHER quality than pro...
# 11     OSS is, on average, of HIGHER quality than pro...
# 17     The quality of OSS and closed source software ...
# 19     OSS is, on average, of HIGHER quality than pro...
# 20     OSS is, on average, of HIGHER quality than pro...
# 21     OSS is, on average, of HIGHER quality than pro...
# 22     The quality of OSS and closed source software ...
# 25     The quality of OSS and closed source software ...
# 26     OSS is, on average, of HIGHER quality than pro...
# 30                                                   NaN
# 31     The quality of OSS and closed source software ...
# 32     OSS is, on average, of HIGHER quality than pro...
# 35     The quality of OSS and closed source software ...
# 36     OSS is, on average, of LOWER quality than prop...
# 44     The quality of OSS and closed source software ...
# 45     OSS is, on average, of HIGHER quality than pro...
# 48     The quality of OSS and closed source software ...
# 49     OSS is, on average, of LOWER quality than prop...
# 50     OSS is, on average, of HIGHER quality than pro...
# 51     OSS is, on average, of HIGHER quality than pro...
# 53     OSS is, on average, of LOWER quality than prop...
# 54     The quality of OSS and closed source software ...
# 56     OSS is, on average, of HIGHER quality than pro...
# 59     OSS is, on average, of HIGHER quality than pro...
# 60     OSS is, on average, of LOWER quality than prop...
# 61     OSS is, on average, of LOWER quality than prop...
# 62     The quality of OSS and closed source software ...
# 66     OSS is, on average, of HIGHER quality than pro...
# 67     OSS is, on average, of LOWER quality than prop...
# 70     The quality of OSS and closed source software ...
# 73     OSS is, on average, of LOWER quality than prop...
# 77     The quality of OSS and closed source software ...
# 79     OSS is, on average, of HIGHER quality than pro...
# 80     The quality of OSS and closed source software ...
# 81     OSS is, on average, of HIGHER quality than pro...
# 84     OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88722  The quality of OSS and closed source software ...
# 88724  OSS is, on average, of HIGHER quality than pro...
# 88725  The quality of OSS and closed source software ...
# 88728  OSS is, on average, of LOWER quality than prop...
# 88734                                                NaN
# 88736  OSS is, on average, of HIGHER quality than pro...
# 88744  OSS is, on average, of HIGHER quality than pro...
# 88745  OSS is, on average, of HIGHER quality than pro...
# 88746  OSS is, on average, of HIGHER quality than pro...
# 88751  OSS is, on average, of HIGHER quality than pro...
# 88754  OSS is, on average, of HIGHER quality than pro...
# 88758  The quality of OSS and closed source software ...
# 88764  The quality of OSS and closed source software ...
# 88767                                                NaN
# 88770  OSS is, on average, of LOWER quality than prop...
# 88771  OSS is, on average, of HIGHER quality than pro...
# 88774  OSS is, on average, of HIGHER quality than pro...
# 88776  OSS is, on average, of HIGHER quality than pro...
# 88778  The quality of OSS and closed source software ...
# 88780  The quality of OSS and closed source software ...
# 88783  OSS is, on average, of HIGHER quality than pro...
# 88786  OSS is, on average, of HIGHER quality than pro...
# 88787  The quality of OSS and closed source software ...
# 88801  The quality of OSS and closed source software ...
# 88804  OSS is, on average, of HIGHER quality than pro...
# 88813  The quality of OSS and closed source software ...
# 88818  OSS is, on average, of HIGHER quality than pro...
# 88820  OSS is, on average, of HIGHER quality than pro...
# 88825  OSS is, on average, of HIGHER quality than pro...
# 88826  OSS is, on average, of HIGHER quality than pro...
# 88836  OSS is, on average, of HIGHER quality than pro...
# 88837  The quality of OSS and closed source software ...
# 88838  The quality of OSS and closed source software ...
# 88841  The quality of OSS and closed source software ...
# 88844                                                NaN
# 88848  The quality of OSS and closed source software ...
# 88853  The quality of OSS and closed source software ...
# 88854  The quality of OSS and closed source software ...
# 88860  The quality of OSS and closed source software ...
# 88865  OSS is, on average, of HIGHER quality than pro...
# 88872  OSS is, on average, of HIGHER quality than pro...
# 88876  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 3                                     Employed full-time
# 4                                     Employed full-time
# 7                     Not employed, but looking for work
# 8                                     Employed full-time
# 9                                     Employed full-time
# 11                                    Employed part-time
# 17                                    Employed full-time
# 19                                    Employed full-time
# 20                                                   NaN
# 21                                    Employed full-time
# 22                                    Employed full-time
# 25                                    Employed full-time
# 26                    Not employed, but looking for work
# 30                Not employed, and not looking for work
# 31                                    Employed full-time
# 32                                    Employed full-time
# 35                                    Employed full-time
# 36                                    Employed part-time
# 44                                    Employed full-time
# 45     Independent contractor, freelancer, or self-em...
# 48                                    Employed full-time
# 49                                    Employed full-time
# 50                                    Employed part-time
# 51                                    Employed full-time
# 53                                    Employed full-time
# 54     Independent contractor, freelancer, or self-em...
# 56                                    Employed full-time
# 59                                    Employed full-time
# 60                                    Employed full-time
# 61                                    Employed full-time
# 62                                    Employed full-time
# 66                                    Employed full-time
# 67                                    Employed full-time
# 70                                    Employed full-time
# 73                                    Employed full-time
# 77                                    Employed full-time
# 79                                    Employed full-time
# 80                                    Employed full-time
# 81                                    Employed full-time
# 84     Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 88722             Not employed, and not looking for work
# 88724  Independent contractor, freelancer, or self-em...
# 88725                 Not employed, but looking for work
# 88728                                 Employed full-time
# 88734  Independent contractor, freelancer, or self-em...
# 88736                                                NaN
# 88744                 Not employed, but looking for work
# 88745                                 Employed full-time
# 88746  Independent contractor, freelancer, or self-em...
# 88751                 Not employed, but looking for work
# 88754                                 Employed full-time
# 88758             Not employed, and not looking for work
# 88764                                                NaN
# 88767                 Not employed, but looking for work
# 88770                                 Employed full-time
# 88771             Not employed, and not looking for work
# 88774                                 Employed full-time
# 88776                 Not employed, but looking for work
# 88778                                 Employed full-time
# 88780  Independent contractor, freelancer, or self-em...
# 88783  Independent contractor, freelancer, or self-em...
# 88786  Independent contractor, freelancer, or self-em...
# 88787                 Not employed, but looking for work
# 88801                                 Employed full-time
# 88804                                 Employed full-time
# 88813  Independent contractor, freelancer, or self-em...
# 88818  Independent contractor, freelancer, or self-em...
# 88820                                                NaN
# 88825                                 Employed full-time
# 88826                                 Employed part-time
# 88836             Not employed, and not looking for work
# 88837                                 Employed part-time
# 88838                                                NaN
# 88841                                                NaN
# 88844                 Not employed, but looking for work
# 88848  Independent contractor, freelancer, or self-em...
# 88853                                 Employed full-time
# 88854                                 Employed full-time
# 88860             Not employed, and not looking for work
# 88865                                            Retired
# 88872                                 Employed part-time
# 88876                                 Employed full-time
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 3               United States              No
# 4                     Ukraine              No
# 7                       India             NaN
# 8                 New Zealand              No
# 9                       India              No
# 11                     Canada  Yes, full-time
# 17         Russian Federation              No
# 19                  Lithuania              No
# 20                     Canada             NaN
# 21              United States              No
# 22              United States              No
# 25              United States              No
# 26                   Colombia  Yes, part-time
# 30                     Canada              No
# 31              United States              No
# 32                  Argentina  Yes, full-time
# 35                    Germany  Yes, full-time
# 36                     Canada  Yes, full-time
# 44              United States              No
# 45              United States              No
# 48                     Serbia  Yes, full-time
# 49                      India              No
# 50              United States  Yes, full-time
# 51                     Poland              No
# 53                     Sweden              No
# 54                  Sri Lanka  Yes, full-time
# 56                     France              No
# 59              United States              No
# 60              United States              No
# 61                Netherlands  Yes, full-time
# 62                      Italy              No
# 66                  Australia              No
# 67                      India              No
# 70                Philippines              No
# 73                    Ireland              No
# 77                      India  Yes, full-time
# 79             United Kingdom              No
# 80                     Poland              No
# 81             United Kingdom              No
# 84                    Germany              No
# ...                       ...             ...
# 88722                  France              No
# 88724                  Israel              No
# 88725                 Belgium              No
# 88728                  Poland             NaN
# 88734      Russian Federation              No
# 88736                  Jordan             NaN
# 88744                  Sweden              No
# 88745                  Brazil              No
# 88746           United States              No
# 88751                  Canada              No
# 88754                   Chile              No
# 88758           United States              No
# 88764           United States              No
# 88767                   Spain              No
# 88770                 Ukraine  Yes, part-time
# 88771                  Canada              No
# 88774            South Africa              No
# 88776                Bulgaria  Yes, part-time
# 88778                 Albania             NaN
# 88780                 Austria  Yes, full-time
# 88783                   India              No
# 88786           United States              No
# 88787                  Brazil              No
# 88801                  Canada              No
# 88804                 Germany              No
# 88813      Russian Federation              No
# 88818           United States              No
# 88820          United Kingdom  Yes, full-time
# 88825                   India              No
# 88826          United Kingdom  Yes, full-time
# 88836                    Oman              No
# 88837                  Poland  Yes, full-time
# 88838                  Canada             NaN
# 88841          United Kingdom              No
# 88844           United States              No
# 88848               Argentina  Yes, part-time
# 88853                   India  Yes, full-time
# 88854          United Kingdom  Yes, full-time
# 88860                  Brazil  Yes, full-time
# 88865             Switzerland              No
# 88872          Czech Republic  Yes, full-time
# 88876                   Spain              No
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8      Some college/university study without earning ...
# 9            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11     Some college/university study without earning ...
# 17           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 19           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 20                                                   NaN
# 21     Some college/university study without earning ...
# 22              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 25     Some college/university study without earning ...
# 26     Some college/university study without earning ...
# 30                             Primary/elementary school
# 31                                      Associate degree
# 32           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 35     Secondary school (e.g. American high school, G...
# 36                                      Associate degree
# 44           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 45              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 48     Some college/university study without earning ...
# 49              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 50     Some college/university study without earning ...
# 51     Some college/university study without earning ...
# 53                                                   NaN
# 54              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 56           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 59     Secondary school (e.g. American high school, G...
# 60     Some college/university study without earning ...
# 61                                      Associate degree
# 62              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 66              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 67              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 70              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 73              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 80           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 81           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 84              Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88722  Some college/university study without earning ...
# 88724           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88725  Some college/university study without earning ...
# 88728  Secondary school (e.g. American high school, G...
# 88734                          Primary/elementary school
# 88736           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88744  Secondary school (e.g. American high school, G...
# 88745          Other doctoral degree (Ph.D, Ed.D., etc.)
# 88746        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88751           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88754                 Professional degree (JD, MD, etc.)
# 88758  Secondary school (e.g. American high school, G...
# 88764  Some college/university study without earning ...
# 88767                          Primary/elementary school
# 88770        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88771                          Primary/elementary school
# 88774           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88776           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88778                                                NaN
# 88780  Secondary school (e.g. American high school, G...
# 88783                                                NaN
# 88786  Secondary school (e.g. American high school, G...
# 88787  Some college/university study without earning ...
# 88801        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88804           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88813        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88818          Other doctoral degree (Ph.D, Ed.D., etc.)
# 88820                                                NaN
# 88825           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88826           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88836        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88837           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88838                          Primary/elementary school
# 88841  Secondary school (e.g. American high school, G...
# 88844           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88848           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88853           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88854           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88860  Secondary school (e.g. American high school, G...
# 88865  Some college/university study without earning ...
# 88872        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88876  Secondary school (e.g. American high school, G...
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 1                                                    NaN
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# 7      Computer science, computer engineering, or sof...
# 8      Computer science, computer engineering, or sof...
# 9                                                    NaN
# 11                             Mathematics or statistics
# 17     Computer science, computer engineering, or sof...
# 19     Information systems, information technology, o...
# 20                                                   NaN
# 21                                                   NaN
# 22     Information systems, information technology, o...
# 25     Computer science, computer engineering, or sof...
# 26     Information systems, information technology, o...
# 30                                                   NaN
# 31     Information systems, information technology, o...
# 32     A natural science (ex. biology, chemistry, phy...
# 35                                                   NaN
# 36     A social science (ex. anthropology, psychology...
# 44     Another engineering discipline (ex. civil, ele...
# 45     Another engineering discipline (ex. civil, ele...
# 48     Computer science, computer engineering, or sof...
# 49     Another engineering discipline (ex. civil, ele...
# 50     Computer science, computer engineering, or sof...
# 51     Computer science, computer engineering, or sof...
# 53     Computer science, computer engineering, or sof...
# 54     Computer science, computer engineering, or sof...
# 56     A business discipline (ex. accounting, finance...
# 59                                                   NaN
# 60     Computer science, computer engineering, or sof...
# 61     Computer science, computer engineering, or sof...
# 62     A natural science (ex. biology, chemistry, phy...
# 66     Information systems, information technology, o...
# 67                         Web development or web design
# 70     Computer science, computer engineering, or sof...
# 73     Computer science, computer engineering, or sof...
# 77     Computer science, computer engineering, or sof...
# 79                             Mathematics or statistics
# 80     Computer science, computer engineering, or sof...
# 81     Computer science, computer engineering, or sof...
# 84     Computer science, computer engineering, or sof...
# ...                                                  ...
# 88722                          Mathematics or statistics
# 88724  Computer science, computer engineering, or sof...
# 88725  Computer science, computer engineering, or sof...
# 88728                                                NaN
# 88734                                                NaN
# 88736                                                NaN
# 88744                                                NaN
# 88745  Computer science, computer engineering, or sof...
# 88746  A social science (ex. anthropology, psychology...
# 88751                                                NaN
# 88754  Computer science, computer engineering, or sof...
# 88758                                                NaN
# 88764                           I never declared a major
# 88767                                                NaN
# 88770  A humanities discipline (ex. literature, histo...
# 88771                                                NaN
# 88774  Computer science, computer engineering, or sof...
# 88776                          Mathematics or statistics
# 88778                                                NaN
# 88780                                                NaN
# 88783                                                NaN
# 88786                                                NaN
# 88787                           I never declared a major
# 88801  Computer science, computer engineering, or sof...
# 88804  Another engineering discipline (ex. civil, ele...
# 88813  Information systems, information technology, o...
# 88818  A health science (ex. nursing, pharmacy, radio...
# 88820  Fine arts or performing arts (ex. graphic desi...
# 88825  Computer science, computer engineering, or sof...
# 88826  Computer science, computer engineering, or sof...
# 88836  Computer science, computer engineering, or sof...
# 88837  Computer science, computer engineering, or sof...
# 88838                                                NaN
# 88841                                                NaN
# 88844  Computer science, computer engineering, or sof...
# 88848  Computer science, computer engineering, or sof...
# 88853                      Web development or web design
# 88854  Computer science, computer engineering, or sof...
# 88860                                                NaN
# 88865  A humanities discipline (ex. literature, histo...
# 88872  Computer science, computer engineering, or sof...
# 88876                                                NaN
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# 7      Taught yourself a new language, framework, or ...
# 8      Taken an online course in programming or softw...
# 9                                                    NaN
# 11     Taken an online course in programming or softw...
# 17     Taken an online course in programming or softw...
# 19     Taken an online course in programming or softw...
# 20     Taught yourself a new language, framework, or ...
# 21     Taken an online course in programming or softw...
# 22     Taken an online course in programming or softw...
# 25     Taught yourself a new language, framework, or ...
# 26     Taken an online course in programming or softw...
# 30                                                   NaN
# 31     Completed an industry certification program (e...
# 32     Taken an online course in programming or softw...
# 35     Taken an online course in programming or softw...
# 36     Taken a part-time in-person course in programm...
# 44     Received on-the-job training in software devel...
# 45     Taken an online course in programming or softw...
# 48     Taught yourself a new language, framework, or ...
# 49     Received on-the-job training in software devel...
# 50     Taken an online course in programming or softw...
# 51     Taught yourself a new language, framework, or ...
# 53     Taken an online course in programming or softw...
# 54     Received on-the-job training in software devel...
# 56     Taken an online course in programming or softw...
# 59     Taught yourself a new language, framework, or ...
# 60     Taken an online course in programming or softw...
# 61     Taken an online course in programming or softw...
# 62     Received on-the-job training in software devel...
# 66     Taken an online course in programming or softw...
# 67     Taken an online course in programming or softw...
# 70     Received on-the-job training in software devel...
# 73     Taken an online course in programming or softw...
# 77     Received on-the-job training in software devel...
# 79     Taken an online course in programming or softw...
# 80     Taken an online course in programming or softw...
# 81     Taken an online course in programming or softw...
# 84     Taken an online course in programming or softw...
# ...                                                  ...
# 88722  Taken an online course in programming or softw...
# 88724  Taken an online course in programming or softw...
# 88725  Taken an online course in programming or softw...
# 88728                                                NaN
# 88734  Taught yourself a new language, framework, or ...
# 88736                                                NaN
# 88744  Taken an online course in programming or softw...
# 88745  Taught yourself a new language, framework, or ...
# 88746  Taken an online course in programming or softw...
# 88751  Taught yourself a new language, framework, or ...
# 88754  Taken an online course in programming or softw...
# 88758  Taken an online course in programming or softw...
# 88764  Completed an industry certification program (e...
# 88767  Taken an online course in programming or softw...
# 88770  Taken an online course in programming or softw...
# 88771  Taught yourself a new language, framework, or ...
# 88774  Taught yourself a new language, framework, or ...
# 88776  Taken an online course in programming or softw...
# 88778                                                NaN
# 88780  Completed an industry certification program (e...
# 88783                                                NaN
# 88786  Taken an online course in programming or softw...
# 88787  Taught yourself a new language, framework, or ...
# 88801  Taken an online course in programming or softw...
# 88804  Taught yourself a new language, framework, or ...
# 88813  Taken a part-time in-person course in programm...
# 88818  Completed an industry certification program (e...
# 88820  Taken an online course in programming or softw...
# 88825  Taken an online course in programming or softw...
# 88826  Taught yourself a new language, framework, or ...
# 88836  Taken an online course in programming or softw...
# 88837  Taken an online course in programming or softw...
# 88838                                                NaN
# 88841  Taken an online course in programming or softw...
# 88844  Taken an online course in programming or softw...
# 88848  Taken an online course in programming or softw...
# 88853  Taken an online course in programming or softw...
# 88854  Taken an online course in programming or softw...
# 88860  Taught yourself a new language, framework, or ...
# 88865  Taken a part-time in-person course in programm...
# 88872  Taught yourself a new language, framework, or ...
# 88876  Taught yourself a new language, framework, or ...
#
#                                                  OrgSize  \
# 0                                                    NaN
# 1                                                    NaN
# 3                                   100 to 499 employees
# 4                               10,000 or more employees
# 7                                                    NaN
# 8                                     10 to 19 employees
# 9                               10,000 or more employees
# 11                                                   NaN
# 17                              1,000 to 4,999 employees
# 19                              1,000 to 4,999 employees
# 20                                                   NaN
# 21                              10,000 or more employees
# 22                              10,000 or more employees
# 25                              10,000 or more employees
# 26                                                   NaN
# 30                                                   NaN
# 31                                  100 to 499 employees
# 32                              10,000 or more employees
# 35                              1,000 to 4,999 employees
# 36                                  100 to 499 employees
# 44                              1,000 to 4,999 employees
# 45     Just me - I am a freelancer, sole proprietor, ...
# 48                                    20 to 99 employees
# 49                              10,000 or more employees
# 50                                                   NaN
# 51                                    20 to 99 employees
# 53                                    20 to 99 employees
# 54                                                   NaN
# 56                              10,000 or more employees
# 59                                  100 to 499 employees
# 60                                    20 to 99 employees
# 61                              10,000 or more employees
# 62                                    20 to 99 employees
# 66                              1,000 to 4,999 employees
# 67                                    10 to 19 employees
# 70                                    20 to 99 employees
# 73                              10,000 or more employees
# 77                                         2-9 employees
# 79                                  500 to 999 employees
# 80                              10,000 or more employees
# 81                              10,000 or more employees
# 84     Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 88722                                                NaN
# 88724  Just me - I am a freelancer, sole proprietor, ...
# 88725                                                NaN
# 88728                           10,000 or more employees
# 88734  Just me - I am a freelancer, sole proprietor, ...
# 88736                                                NaN
# 88744                                                NaN
# 88745                           5,000 to 9,999 employees
# 88746                                      2-9 employees
# 88751                                                NaN
# 88754                               500 to 999 employees
# 88758                                                NaN
# 88764                                                NaN
# 88767                                                NaN
# 88770                                 10 to 19 employees
# 88771                                                NaN
# 88774                                      2-9 employees
# 88776                                                NaN
# 88778                                                NaN
# 88780                                      2-9 employees
# 88783                                                NaN
# 88786  Just me - I am a freelancer, sole proprietor, ...
# 88787                                                NaN
# 88801                           10,000 or more employees
# 88804                           1,000 to 4,999 employees
# 88813                                      2-9 employees
# 88818  Just me - I am a freelancer, sole proprietor, ...
# 88820                                                NaN
# 88825                               500 to 999 employees
# 88826                                 10 to 19 employees
# 88836                                                NaN
# 88837                               100 to 499 employees
# 88838                                                NaN
# 88841                                                NaN
# 88844                                                NaN
# 88848                                                NaN
# 88853                               100 to 499 employees
# 88854                           1,000 to 4,999 employees
# 88860                                                NaN
# 88865                                                NaN
# 88872                               500 to 999 employees
# 88876                                 10 to 19 employees
#
#                                                  DevType           YearsCode  \
# 0                                                    NaN                   4
# 1      Developer, desktop or enterprise applications;...                 NaN
# 3                                  Developer, full-stack                   3
# 4      Academic researcher;Developer, desktop or ente...                  16
# 7         Developer, back-end;Engineer, site reliability                   8
# 8      Database administrator;Developer, back-end;Dev...                  12
# 9      Data or business analyst;Data scientist or mac...                  12
# ...
# 88770                                                Man    No
# 88771                                                Man    No
# 88774                                                Man    No
# 88776                                                Man    No
# 88778                                                NaN   NaN
# 88780                                                Man    No
# 88783                                                NaN   NaN
# 88786                                                Man    No
# 88787                                                Man    No
# 88801                                                Man    No
# 88804                                                Man    No
# 88813                                                Man    No
# 88818                                                Man    No
# 88820  Non-binary, genderqueer, or gender non-conforming   Yes
# 88825                                                Man    No
# 88826                                                Man    No
# 88836                                                Man    No
# 88837                                              Woman    No
# 88838                                              Woman    No
# 88841                                                Man    No
# 88844                                              Woman    No
# 88848  Non-binary, genderqueer, or gender non-conforming    No
# 88853                                                NaN   NaN
# 88854                                              Woman   Yes
# 88860                                                Man    No
# 88865                                                Man    No
# 88872                                                NaN    No
# 88876                                                Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# 7      Straight / Heterosexual
# 8                     Bisexual
# 9                          NaN
# 11     Straight / Heterosexual
# 17     Straight / Heterosexual
# 19     Straight / Heterosexual
# 20                         NaN
# 21     Straight / Heterosexual
# 22     Straight / Heterosexual
# 25              Gay or Lesbian
# 26     Straight / Heterosexual
# 30                         NaN
# 31     Straight / Heterosexual
# 32     Straight / Heterosexual
# 35     Straight / Heterosexual
# 36                         NaN
# 44     Straight / Heterosexual
# 45     Straight / Heterosexual
# 48     Straight / Heterosexual
# 49                         NaN
# 50     Straight / Heterosexual
# 51                         NaN
# 53     Straight / Heterosexual
# 54     Straight / Heterosexual
# 56     Straight / Heterosexual
# 59                    Bisexual
# 60     Straight / Heterosexual
# 61     Straight / Heterosexual
# 62     Straight / Heterosexual
# 66     Straight / Heterosexual
# 67     Straight / Heterosexual
# 70     Straight / Heterosexual
# 73     Straight / Heterosexual
# 77                         NaN
# 79     Straight / Heterosexual
# 80                         NaN
# 81                         NaN
# 84     Straight / Heterosexual
# ...                        ...
# 88722                      NaN
# 88724  Straight / Heterosexual
# 88725  Straight / Heterosexual
# 88728                      NaN
# 88734  Straight / Heterosexual
# 88736                      NaN
# 88744  Straight / Heterosexual
# 88745  Straight / Heterosexual
# 88746  Straight / Heterosexual
# 88751                      NaN
# 88754                      NaN
# 88758  Straight / Heterosexual
# 88764  Straight / Heterosexual
# 88767  Straight / Heterosexual
# 88770  Straight / Heterosexual
# 88771  Straight / Heterosexual
# 88774  Straight / Heterosexual
# 88776  Straight / Heterosexual
# 88778                      NaN
# 88780  Straight / Heterosexual
# 88783                      NaN
# 88786                      NaN
# 88787  Bisexual;Gay or Lesbian
# 88801  Straight / Heterosexual
# 88804                      NaN
# 88813  Straight / Heterosexual
# 88818  Straight / Heterosexual
# 88820                      NaN
# 88825  Straight / Heterosexual
# 88826  Straight / Heterosexual
# 88836  Straight / Heterosexual
# 88837                      NaN
# 88838  Straight / Heterosexual
# 88841  Straight / Heterosexual
# 88844                 Bisexual
# 88848                      NaN
# 88853                      NaN
# 88854                 Bisexual
# 88860  Straight / Heterosexual
# 88865                      NaN
# 88872  Straight / Heterosexual
# 88876  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# 7                                                    NaN        NaN
# 8                           White or of European descent         No
# 9                                                    NaN        Yes
# 11                           Black or of African descent         No
# 17                          White or of European descent        Yes
# 19                          White or of European descent        Yes
# 20                                                   NaN         No
# 21                          White or of European descent        Yes
# 22                           Black or of African descent         No
# 25                                                   NaN         No
# 26                             Hispanic or Latino/Latina         No
# 30                                            East Asian         No
# 31                          White or of European descent         No
# 32                             Hispanic or Latino/Latina         No
# 35                          White or of European descent         No
# 36                          White or of European descent         No
# 44                          White or of European descent         No
# 45                          White or of European descent         No
# 48                          White or of European descent        Yes
# 49                                           South Asian         No
# 50                                           South Asian         No
# 51                                                   NaN         No
# 53                          White or of European descent         No
# 54                                           South Asian        Yes
# 56                                                   NaN         No
# 59                          White or of European descent         No
# 60                          White or of European descent         No
# 61                          White or of European descent         No
# 62                                                   NaN         No
# 66                                           Multiracial         No
# 67                                           South Asian         No
# 70                                East Asian;South Asian         No
# 73                          White or of European descent         No
# 77                                                   NaN        Yes
# 79                                              Biracial         No
# 80                          White or of European descent         No
# 81                                                   NaN         No
# 84                          White or of European descent        NaN
# ...                                                  ...        ...
# 88722  Black or of African descent;East Asian;Middle ...         No
# 88724                       White or of European descent         No
# 88725                       White or of European descent         No
# 88728                       White or of European descent        NaN
# 88734                                                NaN         No
# 88736                                     Middle Eastern        NaN
# 88744                       White or of European descent         No
# 88745                                                NaN        Yes
# 88746                       White or of European descent        Yes
# 88751                       White or of European descent         No
# 88754                          Hispanic or Latino/Latina        Yes
# 88758                                        South Asian         No
# 88764                       White or of European descent        Yes
# 88767                       White or of European descent         No
# 88770                       White or of European descent        Yes
# 88771                       White or of European descent         No
# 88774                       White or of European descent         No
# 88776                       White or of European descent        Yes
# 88778                                                NaN        NaN
# 88780                       White or of European descent         No
# 88783                                                NaN        Yes
# 88786                       White or of European descent         No
# 88787                          Hispanic or Latino/Latina         No
# 88801                                        South Asian        NaN
# 88804                                     Middle Eastern        Yes
# 88813                       White or of European descent         No
# 88818                       White or of European descent        Yes
# 88820  Black or of African descent;East Asian;Hispani...        Yes
# 88825                                                NaN         No
# 88826                       White or of European descent         No
# 88836                       White or of European descent         No
# 88837                       White or of European descent         No
# 88838                       White or of European descent         No
# 88841              White or of European descent;Biracial         No
# 88844                       White or of European descent         No
# 88848                                                NaN         No
# 88853                                                NaN        NaN
# 88854                       White or of European descent         No
# 88860  Hispanic or Latino/Latina;White or of European...         No
# 88865                       White or of European descent         No
# 88872                       White or of European descent         No
# 88876                       White or of European descent         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# 7      Appropriate in length  Neither easy nor difficult
# 8      Appropriate in length  Neither easy nor difficult
# 9                   Too long                   Difficult
# 11     Appropriate in length                        Easy
# 17     Appropriate in length  Neither easy nor difficult
# 19     Appropriate in length                        Easy
# 20     Appropriate in length                        Easy
# 21     Appropriate in length                        Easy
# 22     Appropriate in length                        Easy
# 25     Appropriate in length                        Easy
# 26     Appropriate in length  Neither easy nor difficult
# 30                  Too long  Neither easy nor difficult
# 31     Appropriate in length  Neither easy nor difficult
# 32     Appropriate in length  Neither easy nor difficult
# 35                  Too long  Neither easy nor difficult
# 36     Appropriate in length  Neither easy nor difficult
# 44     Appropriate in length  Neither easy nor difficult
# 45                  Too long  Neither easy nor difficult
# 48                  Too long                        Easy
# 49                  Too long                        Easy
# 50                  Too long                        Easy
# 51     Appropriate in length  Neither easy nor difficult
# 53     Appropriate in length                        Easy
# 54                  Too long  Neither easy nor difficult
# 56     Appropriate in length                        Easy
# 59                       NaN                         NaN
# 60     Appropriate in length                        Easy
# 61     Appropriate in length                        Easy
# 62                  Too long  Neither easy nor difficult
# 66     Appropriate in length                        Easy
# 67     Appropriate in length                        Easy
# 70     Appropriate in length                        Easy
# 73     Appropriate in length  Neither easy nor difficult
# 77     Appropriate in length                        Easy
# 79     Appropriate in length  Neither easy nor difficult
# 80     Appropriate in length                        Easy
# 81                  Too long  Neither easy nor difficult
# 84     Appropriate in length                        Easy
# ...                      ...                         ...
# 88722  Appropriate in length  Neither easy nor difficult
# 88724  Appropriate in length                        Easy
# 88725  Appropriate in length  Neither easy nor difficult
# 88728  Appropriate in length                   Difficult
# 88734               Too long                        Easy
# 88736  Appropriate in length  Neither easy nor difficult
# 88744  Appropriate in length                        Easy
# 88745  Appropriate in length  Neither easy nor difficult
# 88746               Too long  Neither easy nor difficult
# 88751  Appropriate in length  Neither easy nor difficult
# 88754               Too long  Neither easy nor difficult
# 88758               Too long                        Easy
# 88764                    NaN                         NaN
# 88767              Too short                        Easy
# 88770               Too long                        Easy
# 88771  Appropriate in length                        Easy
# 88774               Too long  Neither easy nor difficult
# 88776  Appropriate in length                        Easy
# 88778                    NaN                         NaN
# 88780  Appropriate in length  Neither easy nor difficult
# 88783               Too long                        Easy
# 88786  Appropriate in length                        Easy
# 88787              Too short                        Easy
# 88801               Too long                        Easy
# 88804  Appropriate in length                        Easy
# 88813  Appropriate in length                        Easy
# 88818               Too long  Neither easy nor difficult
# 88820  Appropriate in length                        Easy
# 88825               Too long                   Difficult
# 88826  Appropriate in length                        Easy
# 88836  Appropriate in length                        Easy
# 88837               Too long                        Easy
# 88838  Appropriate in length  Neither easy nor difficult
# 88841  Appropriate in length                        Easy
# 88844  Appropriate in length                        Easy
# 88848  Appropriate in length  Neither easy nor difficult
# 88853                    NaN                         NaN
# 88854  Appropriate in length                        Easy
# 88860              Too short                        Easy
# 88865  Appropriate in length                        Easy
# 88872  Appropriate in length                        Easy
# 88876  Appropriate in length                        Easy
#
# [36443 rows x 85 columns]

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 8        Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 9                            C#;Go;JavaScript;Python;R;SQL
# 11        Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 17                                                Python;R
# 19       Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 20       Assembly;Bash/Shell/PowerShell;C;C++;Go;Java;J...
# 21       Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 22       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 25       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 26               C++;JavaScript;Python;Ruby;SQL;TypeScript
# 30                                                  Python
# 31       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 32                                            C++;Python;R
# 35                                      Java;Kotlin;Python
# 36       Bash/Shell/PowerShell;JavaScript;Python;Other(s):
# 44                                                  Python
# 45       Bash/Shell/PowerShell;C;C#;HTML/CSS;JavaScript...
# 48       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 49       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 50       Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 51       Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;H...
# 53        Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python
# 54                                         Java;Python;SQL
# 56                                       JavaScript;Python
# 59       Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# 60           C++;C#;HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 61       Bash/Shell/PowerShell;C++;Go;HTML/CSS;Java;Jav...
# 62       Bash/Shell/PowerShell;Clojure;Java;Python;Othe...
# 66        C;C#;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 67                         HTML/CSS;Java;JavaScript;Python
# 70                  HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 73             HTML/CSS;Java;JavaScript;Kotlin;Python;Ruby
# 77                  HTML/CSS;Java;JavaScript;Kotlin;Python
# 79       Bash/Shell/PowerShell;C#;F#;Go;HTML/CSS;Java;J...
# 80             Assembly;Bash/Shell/PowerShell;C;C++;Python
# 81       Bash/Shell/PowerShell;C++;HTML/CSS;Java;JavaSc...
# 84       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
#                                ...
# 88722     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python
# 88724                                               Python
# 88725    Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 88728    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88734    Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 88736    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88744             HTML/CSS;Java;JavaScript;PHP;Python;Ruby
# 88745                                   C;Python;Other(s):
# 88746    Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 88751    Assembly;Bash/Shell/PowerShell;C;C++;C#;HTML/C...
# 88754    C;C++;C#;F#;HTML/CSS;Java;JavaScript;PHP;Pytho...
# 88758                               C;HTML/CSS;Java;Python
# 88764    Bash/Shell/PowerShell;C;JavaScript;PHP;Python;...
# 88767     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Python
# 88770                               JavaScript;Python;Ruby
# 88771                                C;C++;HTML/CSS;Python
# 88774    Bash/Shell/PowerShell;C;C++;HTML/CSS;JavaScrip...
# 88776                                        C#;Python;SQL
# 88778                             HTML/CSS;Java;Python;SQL
# 88780    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88783    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88786                     HTML/CSS;JavaScript;Python;Swift
# 88787    Bash/Shell/PowerShell;Elixir;Go;HTML/CSS;JavaS...
# 88801                      Bash/Shell/PowerShell;Go;Python
# 88804    Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Swif...
# 88813                           Java;Python;SQL;TypeScript
# 88818                       Bash/Shell/PowerShell;C;Python
# 88820    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88825                 Bash/Shell/PowerShell;Python;SQL;VBA
# 88826                           HTML/CSS;JavaScript;Python
# 88836                                      C#;Python;R;SQL
# 88837                               Erlang;Java;Python;SQL
# 88838          Assembly;Java;JavaScript;Objective-C;Python
# 88841    Bash/Shell/PowerShell;C++;C#;HTML/CSS;Python;Ruby
# 88844                       HTML/CSS;JavaScript;Python;SQL
# 88848    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 88853     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
