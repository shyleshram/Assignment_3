# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
people = {
    "first": ['Corey','Jane','John'],
    "last": ['Schafer','Doe','Doe'],
    "email": ['CoreyMSchafer@gmail.com','JaneDoe@email.com','JohnDoe@email.com']
}
df1 = pd.DataFrame(people)

# %% [markdown]
# #

# %%
df1
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df['ConvertedComp'].mean()
# Out:
# 127110.73842323056

# %%
df.median()
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
# median() is prefered over median() becoz it is mostly affect by outliers
# few outliers can affect the average very heavily

# %%
df['ConvertedComp'].describe()
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
# count - no of NAN rows

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
filt = df['Hobbyist'] == 'Yes'

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
# 6        Yes
# 7         No
# 8        Yes
# 9        Yes
# 10       Yes
# 11       Yes
# 12        No
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18       Yes
# 19       Yes
# 20        No
# 21       Yes
# 22       Yes
# 23       Yes
# 24       Yes
# 25        No
# 26       Yes
# 27       Yes
# 28       Yes
# 29       Yes
# 30        No
# 31        No
# 32        No
# 33        No
# 34       Yes
# 35        No
# 36       Yes
# 37       Yes
# 38       Yes
# 39       Yes
# 40       Yes
# 41       Yes
# 42       Yes
#         ...
# 82789    Yes
# 82805    Yes
# 83000     No
# 83397    Yes
# 83511     No
# 83612    Yes
# 83648     No
# 83709    Yes
# 83777     No
# 83786     No
# 83800     No
# 83862    Yes
# 84299    Yes
# 84539    Yes
# 85182     No
# 85208     No
# 85396     No
# 85538     No
# 85642     No
# 85738    Yes
# 85744     No
# 85955    Yes
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].count()
# Out:
# 88883

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df.shape
# Out:
# (88883, 84)

# %%
df['SocialMedia']
# Out:
# Respondent
# 1                         Twitter
# 2                       Instagram
# 3                          Reddit
# 4                          Reddit
# 5                        Facebook
# 6                         YouTube
# 7                         YouTube
# 8                         YouTube
# 9                         Twitter
# 10                        YouTube
# 11                            NaN
# 12                         Reddit
# 13                        Twitter
# 14                         Reddit
# 15                        YouTube
# 16                        YouTube
# 17                        YouTube
# 18                  VK ВКонта́кте
# 19                       WhatsApp
# 20                       Facebook
# 21       I don't use social media
# 22                      Instagram
# 23                         Reddit
# 24                         Reddit
# 25                        YouTube
# 26       I don't use social media
# 27                        YouTube
# ...

# %%
df['SocialMedia'].count()
# Out:
# 84437

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
schema_df.loc['MainBranch','QuestionText']
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."'

# %%
df['SocialMedia'].value_counts().sort_values()
# Out:
# Hello                          19
# Youku Tudou 优酷                 21
# Weibo 新浪微博                     56
# VK ВКонта́кте                 603
# Snapchat                      628
# WeChat 微信                     667
# LinkedIn                     4501
# I don't use social media     5554
# Instagram                    6261
# Twitter                     11398
# Facebook                    13178
# WhatsApp                    13347
# YouTube                     13830
# Reddit                      14374
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True) # gives percentage
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
# GROUPING OF THE DATA

# %%
# GROUPING -> groupby() - combination of SPLIT, APPLY FUNCTION, COMBINE_RESULTS

# %%
df['Country'].value_counts()
# Out:
# United States                            20949
# India                                     9061
# Germany                                   5866
# United Kingdom                            5737
# Canada                                    3395
# France                                    2391
# Brazil                                    1948
# Poland                                    1922
# Australia                                 1903
# Netherlands                               1852
# Russian Federation                        1694
# Spain                                     1604
# Italy                                     1576
# Sweden                                    1274
# Switzerland                                978
# Israel                                     952
# Turkey                                     949
# Pakistan                                   923
# Ukraine                                    868
# Austria                                    839
# ...

# %%
# 1. Splitting the object

# %%
country_grp = df.groupby(['Country']) # grouping rows by country

# %%
country_grp

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 13                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# 23                             I am a developer by profession      Yes
# 26                             I am a developer by profession      Yes
# 29                             I am a developer by profession      Yes
# 32                             I am a developer by profession       No
# 35                             I am a developer by profession       No
# 39                             I am a developer by profession      Yes
# 45          I am not primarily a developer, but I write co...      Yes
# 46                             I am a developer by profession      Yes
# 47                             I am a developer by profession      Yes
# ...

# %%
filt = df['Country'] == 'United States'

# %%
df.loc[filt]['SocialMedia'].value_counts().head()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['United States']
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country                               SocialMedia
# Afghanistan                           Facebook                     15
#                                       YouTube                       9
#                                       I don't use social media      6
#                                       WhatsApp                      4
#                                       Instagram                     1
#                                       LinkedIn                      1
#                                       Twitter                       1
# Albania                               WhatsApp                     18
#                                       Facebook                     16
#                                       Instagram                    13
#                                       YouTube                      10
#                                       Twitter                       8
#                                       LinkedIn                      7
# ...

# %%
x = df.groupby(['Country'])

# %%
x

# %%
x.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 13                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# 23                             I am a developer by profession      Yes
# 26                             I am a developer by profession      Yes
# 29                             I am a developer by profession      Yes
# 32                             I am a developer by profession       No
# 35                             I am a developer by profession       No
# 39                             I am a developer by profession      Yes
# 45          I am not primarily a developer, but I write co...      Yes
# 46                             I am a developer by profession      Yes
# 47                             I am a developer by profession      Yes
# ...

# %%
x['SocialMedia']

# %%
x['SocialMedia'].value_counts()
# Out:
# Country                               SocialMedia
# Afghanistan                           Facebook                     15
#                                       YouTube                       9
#                                       I don't use social media      6
#                                       WhatsApp                      4
#                                       Instagram                     1
#                                       LinkedIn                      1
#                                       Twitter                       1
# Albania                               WhatsApp                     18
#                                       Facebook                     16
#                                       Instagram                    13
#                                       YouTube                      10
#                                       Twitter                       8
#                                       LinkedIn                      7
# ...

# %%
x['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
x['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %%
x['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
x['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                                    6222.0
# Albania                                       10818.0
# Algeria                                        7878.0
# Andorra                                      160931.0
# Angola                                         7764.0
# Antigua and Barbuda                               NaN
# Argentina                                     17760.0
# Armenia                                       19692.0
# Australia                                     79783.0
# Austria                                       51559.0
# Azerbaijan                                    15858.0
# Bahamas                                           NaN
# Bahrain                                       15912.0
# Bangladesh                                     8764.0
# Barbados                                      21000.0
# Belarus                                       24000.0
# Belgium                                       48120.0
# ...

# %%
# aggregate - ex: if we want to see both median and mean -> use agg()

# %%
x['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                              median           mean
# Country
# Afghanistan                                  6222.0  101953.333333
# Albania                                     10818.0   21833.700000
# Algeria                                      7878.0   34924.047619
# Andorra                                    160931.0  160931.000000
# Angola                                       7764.0    7764.000000
# Antigua and Barbuda                             NaN            NaN
# Argentina                                   17760.0   29467.265306
# Armenia                                     19692.0   24691.733333
# Australia                                   79783.0  171541.116279
# Austria                                     51559.0   83955.639604
# Azerbaijan                                  15858.0   15785.750000
# Bahamas                                         NaN            NaN
# Bahrain                                     15912.0   23934.000000
# ...

# %%
x['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
# groupby and aggregation

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 13                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# 23                             I am a developer by profession      Yes
# 26                             I am a developer by profession      Yes
# 29                             I am a developer by profession      Yes
# 32                             I am a developer by profession       No
# 35                             I am a developer by profession       No
# 39                             I am a developer by profession      Yes
# 45          I am not primarily a developer, but I write co...      Yes
# 46                             I am a developer by profession      Yes
# 47                             I am a developer by profession      Yes
# ...

# %%
#country_grp['SocialMedia'].value_counts().loc['United States']
country_grp['SocialMedia'].value_counts().loc['United States']
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['ConvertedComp'].agg(['median','mean'])
# Out:
#                                              median           mean
# Country
# Afghanistan                                  6222.0  101953.333333
# Albania                                     10818.0   21833.700000
# Algeria                                      7878.0   34924.047619
# Andorra                                    160931.0  160931.000000
# Angola                                       7764.0    7764.000000
# Antigua and Barbuda                             NaN            NaN
# Argentina                                   17760.0   29467.265306
# Armenia                                     19692.0   24691.733333
# Australia                                   79783.0  171541.116279
# Austria                                     51559.0   83955.639604
# Azerbaijan                                  15858.0   15785.750000
# Bahamas                                         NaN            NaN
# Bahrain                                     15912.0   23934.000000
# ...

# %%
filt = df['Country'] == 'India'

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# ...

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_respondents = df['Country'].value_counts()
country_respondents

# %%
country_grp = df.groupby(['Country'])

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python

# %%
python_df = pd.concat([country_respondents,country_uses_python], axis='columns',sort=False)

# %%
python_df

# %%
python_df.columns = {'Country':'NumRespondents','LanguageWorkedWith':'NumKnowsPython'}

# %%
python_df

# %%
python_df.rename(columns={'Country':'NumRespondents','LanguageWorkedWith':'NumKnowsPython'}, inplace=True)

# %%
python_df['Percentage'] = (python_df['NumKnowsPython']/python_df['NumRespondents'])*100

# %%
python_df.sort_values('Percentage',ascending=False, inplace=True)

# %%
python_df

# %%
python_df.loc['Japan']
